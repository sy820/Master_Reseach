# %% [markdown]
# ## Result

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import pandas as pd
import numpy as np
import pickle as pkl

f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational = pkl.load(f)
f.close()
oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')
oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_noaug_oof_df.csv')
oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df_netweight.csv')

TK, PK = oof['KIc'], oof['preds']
TKfv, PKfv = oof2['KIc'], oof2['preds']
TKv, PKv = oof3['KIc'], oof3['preds']

# フォントファイルのパスを指定
font_path = './Times New Roman.ttf'  # ここにTimes New Romanのフォントファイルのパスを入力
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23
plt.figure(figsize=(10, 20))

plt.subplot(1,2,1)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(plot_Y_rational[0][3], plot_Y_rational[1][3],".",c="black",label="test-folds")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("Predicted KIc", fontproperties=font_prop)
plt.title("VGG16 + GP\n w/o fine-tuning", fontproperties=font_prop)
plt.legend(loc="lower right",fontsize=20, prop=font_prop)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, 
         "RMSE(test)="+str(str(np.sqrt(np.mean((plot_Y_rational[0][3] - plot_Y_rational[1][3])**2)))[:5]), 
         size=24, color="black", 
         fontproperties=font_prop)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplot(1,2,2)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TKfv, PKfv,".",c="black",label="test-folds")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("Predicted KIc", fontproperties=font_prop)
plt.title("ViT\n w/ fine-tuning", fontproperties=font_prop)
plt.legend(loc="lower right",fontsize=20, prop=font_prop)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(np.sqrt(np.mean((TKfv - PKfv)**2)))[:5], 
         size=24, color="black", 
         fontproperties=font_prop)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplots_adjust(wspace=0.3)
plt.savefig('./Figure/GGplot4.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle as pkl

f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational = pkl.load(f)
f.close()
oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_trainaug_oof_df.csv')
oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_trainaug_oof_df.csv')

TK, PK = oof['KIc'], oof['preds']
TKv, PKv = oof2['KIc'], oof2['preds']

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23

plt.subplot(1,3,1)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(plot_Y_rational[0][3], plot_Y_rational[1][3],".",c="black",label="test-folds")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("Predicted KIc", fontproperties=font_prop)
plt.title("VGG16 + GP\n w/o fine-tuning", fontproperties=font_prop)
plt.legend(loc="lower right",fontsize=20, prop=font_prop)
plt.xlim(1,5)
plt.ylim(1,5)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.text(1.05, 4.7, 
         "RMSE(test)="+str(str(np.sqrt(np.mean((plot_Y_rational[0][3] - plot_Y_rational[1][3])**2)))[:5]), 
         size=24, color="black", 
         fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplot(1,3,2)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TK, PK,".",c="black",label="test-folds")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("Predicted KIc", fontproperties=font_prop)
plt.title("VGG16\n w/ fine-tuning", fontproperties=font_prop)
plt.legend(loc="lower right",fontsize=20, prop=font_prop)
plt.xlim(1,5)
plt.ylim(1,5)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.text(1.05, 4.7, 
         "RMSE(test)="+str(np.sqrt(np.mean((TK - PK)**2)))[:5], 
         size=24, color="black", 
         fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplot(1,3,3)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TKv, PKv,".",c="black",label="test-folds")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("Predicted KIc", fontproperties=font_prop)
plt.title("ViT\n w/ fine-tuning", fontproperties=font_prop)
plt.legend(loc="lower right",fontsize=20, prop=font_prop)
plt.xlim(1,5)
plt.ylim(1,5)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.text(1.05, 4.7, 
         "RMSE(test)="+str(np.sqrt(np.mean((TKv - PKv)**2)))[:5], 
         size=24, color="black", 
         fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplots_adjust(wspace=0.3)
plt.savefig('./Figure/GGplot.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# data
# oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')
# oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')\
#     .sort_values(by='Id').reset_index(drop=True)
# f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
# plot_Y_rational = pkl.load(f)
# f.close()

f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational = pkl.load(f)
f.close()
oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_trainaug_oof_df.csv')
oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_trainaug_oof_df.csv')\
    .sort_values(by='Id').reset_index(drop=True)


oof['VGG+GP_preds'] = plot_Y_rational[1][3]
oof = oof.sort_values(by='Id').reset_index(drop=True)

# diff definition
oof['vgg_diff'] = abs(oof['preds'] - oof['KIc'])
oof2['vit_diff'] = abs(oof2['preds'] - oof2['KIc'])
vgg_gp = abs(oof['VGG+GP_preds'] - oof['KIc'])

# plot
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 16
plt.subplot(1,3,1)
plt.plot(oof2['KIc'], (oof['vgg_diff'] - oof2['vit_diff']),".", c="black")
plt.plot([-1,5],[0,0],"-",c="black")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("VGG(error)-ViT(error)", fontproperties=font_prop)
plt.title("ViT vs VGG16", fontproperties=font_prop)
plt.xlim(1, 5)
plt.ylim(-2, 2)
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([-2, -1, 0, 1, 2])
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplot(1,3,2)
plt.plot(oof2['KIc'], vgg_gp - oof['vgg_diff'],".", c="black")
plt.plot([-1,5],[0,0],"-",c="black")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("VGG+GP(error)-VGG(error)", fontproperties=font_prop)
plt.title("VGG16 vs VGG16+GP", fontproperties=font_prop)
plt.xlim(1, 5)
plt.ylim(-2, 2)
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([-2, -1, 0, 1, 2])
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplot(1,3,3)
plt.plot(oof2['KIc'], vgg_gp - oof2['vit_diff'],".", c="black")
plt.plot([-1,5],[0,0],"-",c="black")
plt.xlabel("True KIc", fontproperties=font_prop)
plt.ylabel("VGG+GP(error)-ViT(error)", fontproperties=font_prop)
plt.title("ViT vs VGG16+GP", fontproperties=font_prop)
plt.xlim(1, 5)
plt.ylim(-2, 2)
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([-2, -1, 0, 1, 2])
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.gca().set_aspect('equal', adjustable='box')

plt.subplots_adjust(wspace=0.3)
plt.savefig('./Figure/diff.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()

# %%
from scipy import stats
from matplotlib import font_manager as fm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
 
np.random.seed(0)
 # フォントファイルのパスを指定
font_path = './Times New Roman.ttf'  # ここにTimes New Romanのフォントファイルのパスを入力
font_prop = fm.FontProperties(fname=font_path)

def barplot_annotate_brackets(num1, num2, data, center, 
                              height, yerr=None, dh=.05, 
                              barh=.05, fs=None, maxasterix=None):
    # plt.figure(figsize=(5, 5))
    # plt.gca().set_aspect('equal', adjustable='box')
    """ 
    Annotate barplot with p-values.
  
    :param num1: number of left bar to put bracket over
    :param num2: number of right bar to put bracket over
    :param data: string to write or number for generating asterixes
    :param center: centers of all bars (like plt.bar() input)
    :param height: heights of all bars (like plt.bar() input)
    :param yerr: yerrs of all bars (like plt.bar() input)
    :param dh: height offset over bar / bar + yerr in axes coordinates (0 to 1)
    :param barh: bar height in axes coordinates (0 to 1)
    :param fs: font size
    :param maxasterix: maximum number of asterixes to write (for very small p-values)
    """
  
    if type(data) is str:
        text = data
    else:
        # * is p < 0.05
        # ** is p < 0.005
        # *** is p < 0.0005
        # ↓↓↓↓↓↓↓↓↓↓↓
        # * is p < 0.05
        # ** is p < 0.01
        # *** is p < 0.001
        # etc.
        text = ''
        p = .05
  
        while data < p:
            text += '*'
            p /= 10.
  
            if maxasterix and len(text) == maxasterix:
                break
        
        if data >= 0.1:
            text = 'n. s.'
        elif data < 0.1 and data >= 0.05:
            text = '†'
        elif data < 0.05 and data >= 0.01:
            text = 'p < 0.05'
        elif data < 0.01 and data >= 0.001:
            text = 'p < 0.01'
        elif data < 0.001:
            text = '***'
        
  
    lx, ly = center[num1], height[num1]
    rx, ry = center[num2], height[num2]
  
    if yerr:
        ly += yerr[num1]
        ry += yerr[num2]
  
    ax_y0, ax_y1 = plt.gca().get_ylim()
    dh *= (ax_y1 - ax_y0)
    barh *= (ax_y1 - ax_y0)
  
    y = max(ly, ry) + dh
  
    barx = [lx, lx, rx, rx]
    bary = [y, y+barh, y+barh, y]
    mid = ((lx+rx)/2, y+barh)
  
    plt.plot(barx, bary, c='black')
  
    kwargs = dict(ha='center', va='bottom')
    if fs is not None:
        kwargs['fontsize'] = fs
  
    plt.text(*mid, text, **kwargs, fontproperties=font_prop)
    
    #ボックス作成
    pos = plt.gca().get_position()
    s_text = "n. s. : not significant\n† : p < 0.1\n* : p < 0.05\n** : p < 0.01 \
             \n*** : p < 0.001"
    dic_box = {
        'facecolor' : 'whitesmoke',
        'edgecolor' : 'black',
        'linewidth' : 1
    }

    #文字とボックスの挿入
    # plt.text(5.5, 0.20, s=s_text, 
    #         color='black', ha='center', fontsize='13', 
    #         bbox=dic_box)
    
""" main """
## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof2 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed10_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof3 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed20_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof4 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed51_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof5 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed111_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof6 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed19_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof7 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed23_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof8 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed34_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof9 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed40_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof10 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed56_bootstrap_trainaug_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed10_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed20_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof4 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed51_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof5 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed111_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof6 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed19_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof7 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed23_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof8 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed34_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof9 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed40_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof10 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed56_bootstrap_trainaug_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)

vgg_rmse = []
vit_rmse = []

vgg_rmse.append(mean_squared_error(vgg_oof['KIc'], vgg_oof['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof['KIc'], vit_oof['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof2['KIc'], vgg_oof2['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof2['KIc'], vit_oof2['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof3['KIc'], vgg_oof3['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof3['KIc'], vit_oof3['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof4['KIc'], vgg_oof4['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof4['KIc'], vit_oof4['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof5['KIc'], vgg_oof5['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof5['KIc'], vit_oof5['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof6['KIc'], vgg_oof6['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof6['KIc'], vit_oof6['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof7['KIc'], vgg_oof7['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof7['KIc'], vit_oof7['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof8['KIc'], vgg_oof8['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof8['KIc'], vit_oof8['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof9['KIc'], vgg_oof9['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof9['KIc'], vit_oof9['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof10['KIc'], vgg_oof10['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof10['KIc'], vit_oof10['preds'], squared=False))

# Generate toy data
x0 = vit_rmse
x1 = vgg_rmse
 
# Welch’s t-test
t01_value, p01_value = stats.ttest_rel(vgg_rmse, vit_rmse, alternative='greater') 
 
""" plot """
n = 10
heights = [0, np.mean(x0), 0, np.mean(x1), 0]
std = [0, np.std(x0), 0, np.std(x1), 0]
label = ['', 'ViT', '', 'VGG', '']
width = 0.8 # the width of the bars
bars = np.arange(n)
  
# データの作成
data = pd.DataFrame({
    'Method': ['ViT'] * n + ['VGG'] * n,
    'RMSE': vit_rmse + vgg_rmse
})

# 箱ひげ図と点を結ぶグラフの描画
plt.figure(figsize=(5, 5))
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23 
plt.xticks([0, 1, 2, 3, 4], label, fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)

# 各点を結ぶ線の描画
for i in range(0, n):
    method1 = data['RMSE'][i]
    method2 = data['RMSE'][i+n]
    plt.plot([1, 3], [method1, method2], color="black", marker='.', markersize=12, 
             linestyle="-", linewidth=2)   

# グラフの装飾
plt.xlabel("Method", fontproperties=font_prop)
plt.ylabel("RMSE", fontproperties=font_prop)
plt.ylim(0.2, 0.245)
plt.xlim(0, 4)
# plt.title("ViT vs VGG")
barplot_annotate_brackets(1, 3, p01_value, bars, heights, yerr=std, dh=.3)

plt.tight_layout()
plt.savefig('./Figure/paired_ttest_b.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()

# plt.bar(bars, heights, width, tick_label=label, yerr=std,
#         align='center', alpha=0.5, ecolor='black', capsize=5)
# Out:
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import pandas as pd
import pickle as pkl

## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
true_kic = vgg_oof['KIc']  
predicted_kic = vgg_oof['preds'] 

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
true_kic_vit = vit_oof['KIc']  
predicted_kic_vit = vit_oof['preds']  

## vgg+GP
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational42 = pkl.load(f)
f.close() 
true_kic_vgg_gau = pd.Series(plot_Y_rational42[0][3])  
predicted_kic_vgg_gau = pd.Series(plot_Y_rational42[1][3])  
      
# 区切りの数
num_bins = 9

# 区切りの幅を計算
bin_width = (np.max(true_kic) - np.min(true_kic)) / num_bins

# 区切りごとにPredicted KICの平均値を計算
bin_centers = []
predicted_kic_means = []
predicted_kic_means_vit = []
predicted_kic_means_vgg_gau = []
predicted_kic_std = []
predicted_kic_std_vit = []
predicted_kic_std_vgg_gau = []

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23
plt.figure(figsize=(5, 5))

for i in range(num_bins):
    bin_lower = np.min(true_kic) + i * bin_width
    bin_upper = bin_lower + bin_width
    plt.vlines(bin_lower, 1, 5, colors="gray")
    
    bin_mask = (true_kic >= bin_lower) & (true_kic < bin_upper)
    bin_true_kic = true_kic[bin_mask]
    bin_predicted_kic = predicted_kic[bin_mask]
    bin_centers.append((bin_lower + bin_upper) / 2)
    predicted_kic_means.append(np.mean(bin_predicted_kic))
    predicted_kic_std.append(bin_predicted_kic.std(ddof=0) / np.sqrt(len(bin_predicted_kic)))
    
    bin_mask_vit = (true_kic_vit >= bin_lower) & (true_kic_vit < bin_upper)
    bin_true_kic_vit = true_kic_vit[bin_mask_vit]
    bin_predicted_kic_vit = predicted_kic_vit[bin_mask_vit]
    predicted_kic_means_vit.append(np.mean(bin_predicted_kic_vit))
    predicted_kic_std_vit.append(bin_predicted_kic_vit.std(ddof=0) / \
                                 np.sqrt(len(bin_predicted_kic_vit)))
    
    bin_mask_vgg_gau = (true_kic_vgg_gau >= bin_lower) & (true_kic_vgg_gau < bin_upper)
    bin_true_kic_vgg_gau = true_kic_vgg_gau[bin_mask_vgg_gau]
    bin_predicted_kic_vgg_gau = predicted_kic_vgg_gau[bin_mask_vgg_gau]
    predicted_kic_means_vgg_gau.append(np.mean(bin_predicted_kic_vgg_gau))
    predicted_kic_std_vgg_gau.append(bin_predicted_kic_vgg_gau.std(ddof=0) / \
                                     np.sqrt(len(bin_predicted_kic_vgg_gau)))

plt.vlines(bin_upper, 1, 5, colors="gray")
plt.plot([np.min(true_kic), np.max(true_kic)], [np.min(true_kic), np.max(true_kic)], "-", c="gray")
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(bin_centers, predicted_kic_means_vgg_gau, 'b-', label='VGG16 + GP (no fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means_vgg_gau+np.array(predicted_kic_std_vgg_gau), 
                 predicted_kic_means_vgg_gau-np.array(predicted_kic_std_vgg_gau), 
                 alpha=0.15)
plt.plot(bin_centers, predicted_kic_means, 'r-', label='VGG16 (fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means+np.array(predicted_kic_std), 
                 predicted_kic_means-np.array(predicted_kic_std), alpha=0.15)
plt.plot(bin_centers, predicted_kic_means_vit, 'g-', label='ViT (fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means_vit+np.array(predicted_kic_std_vit), 
                 predicted_kic_means_vit-np.array(predicted_kic_std_vit), alpha=0.15)

plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("Systematic error for each model", x=0.5, y=1.05)
plt.legend(loc="upper left",fontsize=10)
plt.xlim(1,5)
plt.ylim(1,5)
plt.savefig('./Figure/average_grit_plot_42seed.png', bbox_inches="tight", pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import pandas as pd
import cv2

id = 101783
fracture_image_path = '/home/yamanaka/Master_research/Mototake_Analysis/VGG+GP/imagedata/' + str(id) + '.jpg'
attention_distance_path = '/home/yamanaka/Master_research/KIc/Image/Attention_Distance/middle/' + str(id) + '.jpg'

font_path = './Times New Roman.ttf'  # ここにTimes New Romanのフォントファイルのパスを入力
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23
plt.figure(figsize=(10, 20))

plt.subplot(1,2,1)
fi_img = cv2.imread(fracture_image_path)
plt.imshow(fi_img)
plt.axis('off')
plt.xlabel('(a)Fracture Image', fontproperties=font_prop)

plt.subplot(1,2,2)
ad_img = cv2.imread(attention_distance_path)
ad_img = cv2.cvtColor(ad_img, cv2.COLOR_BGR2RGB)
plt.imshow(ad_img)
plt.axis('off')
plt.xlabel('(b)Attention Distance', fontproperties=font_prop)
plt.show()
plt.savefig('./Figure/fi_ad.eps')
