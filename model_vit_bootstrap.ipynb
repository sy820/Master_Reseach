# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import sys
import math
import time
import random
import shutil
from pathlib import Path
from contextlib import contextmanager
from collections import defaultdict, Counter

import scipy as sp
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold

from tqdm.auto import tqdm
from functools import partial

import cv2
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.models as models
from torch.nn.parameter import Parameter
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, CosineAnnealingLR, ReduceLROnPlateau

import albumentations as A
from albumentations.pytorch import ToTensorV2
from albumentations import ImageOnlyTransform

from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM

sys.path.append('../input/pytorch-image-models/pytorch-image-models-master')
import timm

from torch.cuda.amp import autocast, GradScaler

import warnings
warnings.filterwarnings('ignore')

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
# Out:
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warn(f"Failed to load image Python extension: {e}")

# %%
# ====================================================
# CFG
# ====================================================
class CFG:
    apex=False
    debug=False
    print_freq=10
    num_workers=0
    size=224
    model_name='vit_large_patch32_224'
    scheduler='CosineAnnealingLR' # ['ReduceLROnPlateau', 'CosineAnnealingLR', 'CosineAnnealingWarmRestarts']
    epochs=40
    #factor=0.2 # ReduceLROnPlateau
    #patience=4 # ReduceLROnPlateau
    #eps=1e-6 # ReduceLROnPlateau
    T_max=3 # CosineAnnealingLR
    #T_0=3 # CosineAnnealingWarmRestarts
    lr=1e-4
    min_lr=1e-6
    batch_size=32
    weight_decay=1e-6
    gradient_accumulation_steps=1
    max_grad_norm=1000
    # seed= [42, 10, 20, 51, 111]
    seed = [42]
    # seed = [19, 23, 34, 40, 56]
    # seed = [19, 23, 34, 40, 56, 77, 88, 99, 12, 45, 67, 78, 89]
    # seed = [18, 24]
    target_size=1
    target_col='KIc'
    n_fold=5
    kfold="Kfold" #or Kfold
    trn_fold = [i for i in range(n_fold)]
    train=True
    grad_cam=True
      
# ====================================================
# Directory settings
# ====================================================
import os

OUTPUT_DIR = './KIc/Model/vit/'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
# ====================================================
# Utils
# ====================================================
def get_score(y_true, y_pred):
    score = mean_squared_error(y_true, y_pred, squared=False) # RMSE
    return score


def init_logger(log_file=OUTPUT_DIR+'train.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = init_logger()


def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %%
# ====================================================
# Dataset
# ====================================================
class TrainDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['file_path'].values
        self.labels = df[CFG.target_col].values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_path = self.file_names[idx]
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            image = self.transform(image=image)['image']
        label = torch.tensor(self.labels[idx]).float()
        return image, label

# %%
# ====================================================
# Transforms
# ====================================================
def get_transforms(*, data):
    
    if data == 'train':
        return A.Compose([
            A.Resize(CFG.size, CFG.size),
            A.RandomResizedCrop(CFG.size, CFG.size, scale=(0.85, 1.0)),
            A.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

    elif data == 'valid':
        return A.Compose([
            A.Resize(CFG.size, CFG.size),
            A.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %%
# ====================================================
# MODEL
# ====================================================
class CustomModel(nn.Module):
    def __init__(self, cfg, pretrained=False):
        super().__init__()
        self.cfg = cfg
        self.model = timm.create_model(self.cfg.model_name, pretrained=pretrained)
        self.n_features = self.model.head.in_features
        self.model.head = nn.Identity()
        self.fc = nn.Linear(self.n_features, self.cfg.target_size)

    def feature(self, image):
        feature = self.model(image)
        return feature
        
    def forward(self, image):
        feature = self.feature(image)
        output = self.fc(feature)
        return output

# %%
# ====================================================
# Loss
# ====================================================
class RMSELoss(nn.Module):
    def __init__(self, eps=1e-6):
        super().__init__()
        self.mse = nn.MSELoss()
        self.eps = eps

    def forward(self, yhat, y):
        loss = torch.sqrt(self.mse(yhat, y) + self.eps)
        return loss

# %%
# ====================================================
# Helper functions
# ====================================================
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))


def train_fn(fold, train_loader, model, criterion, optimizer, epoch, scheduler, device):
    model.train()
    if CFG.apex:#使わないところは消す
        scaler = GradScaler()
    losses = AverageMeter()
    start = end = time.time()
    global_step = 0
    for step, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        if CFG.apex:
            with autocast():
                y_preds = model(images)
                loss = criterion(y_preds.view(-1), labels)
        else:
            y_preds = model(images)
            loss = criterion(y_preds.view(-1), labels)
        # record loss
        losses.update(loss.item(), batch_size)
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        if CFG.apex:
            scaler.scale(loss).backward()
        else:
            loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), CFG.max_grad_norm)
        if (step + 1) % CFG.gradient_accumulation_steps == 0:
            if CFG.apex:
                scaler.step(optimizer)
                scaler.update()
            else:
                optimizer.step()
            optimizer.zero_grad()
            global_step += 1
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  'Grad: {grad_norm:.4f}  '
                  'LR: {lr:.6f}  '
                  .format(epoch+1, step, len(train_loader), 
                          remain=timeSince(start, float(step+1)/len(train_loader)),
                          loss=losses,
                          grad_norm=grad_norm,
                          lr=scheduler.get_lr()[0]))

    return losses.avg


def valid_fn(valid_loader, model, criterion, device):
    model.eval()
    losses = AverageMeter()
    preds = []
    start = end = time.time()
    for step, (images, labels) in enumerate(valid_loader):
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        # compute loss
        with torch.no_grad():
            y_preds = model(images)
        loss = criterion(y_preds.view(-1), labels)
        losses.update(loss.item(), batch_size)
        # record accuracy
        preds.append(y_preds.to('cpu').numpy())
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(valid_loader)-1):
            print('EVAL: [{0}/{1}] '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  .format(step, len(valid_loader),
                          loss=losses,
                          remain=timeSince(start, float(step+1)/len(valid_loader))))
    predictions = np.concatenate(preds)
    return losses.avg, predictions

# %%
# ====================================================
# Train loop
# ====================================================
def train_loop(folds, fold, seed):
    
    LOGGER.info(f"========== fold: {fold} training ==========")

    # ====================================================
    # loader
    # ====================================================
    trn_idx = folds[folds['fold'] != fold].index
    val_idx = folds[folds['fold'] == fold].index

    train_folds = folds.loc[trn_idx].reset_index(drop=True)
    valid_folds = folds.loc[val_idx].reset_index(drop=True)
    valid_labels = valid_folds[CFG.target_col].values

    train_dataset = TrainDataset(train_folds, transform=get_transforms(data='train'))
    valid_dataset = TrainDataset(valid_folds, transform=get_transforms(data='valid'))

    train_loader = DataLoader(train_dataset,
                              batch_size=CFG.batch_size, 
                              shuffle=True, 
                              num_workers=CFG.num_workers, pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset, 
                              batch_size=CFG.batch_size * 2, 
                              shuffle=False, 
                              num_workers=CFG.num_workers, pin_memory=True, drop_last=False)
    
    # ====================================================
    # scheduler 
    # ====================================================
    def get_scheduler(optimizer):
        if CFG.scheduler=='ReduceLROnPlateau':
            scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=CFG.factor, patience=CFG.patience, verbose=True, eps=CFG.eps)
        elif CFG.scheduler=='CosineAnnealingLR':
            scheduler = CosineAnnealingLR(optimizer, T_max=CFG.T_max, eta_min=CFG.min_lr, last_epoch=-1)
        elif CFG.scheduler=='CosineAnnealingWarmRestarts':
            scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=CFG.T_0, T_mult=1, eta_min=CFG.min_lr, last_epoch=-1)
        return scheduler

    # ====================================================
    # model & optimizer
    # ====================================================
    model = CustomModel(CFG, pretrained=True)
    model.to(device)

    optimizer = Adam(model.parameters(), lr=CFG.lr, weight_decay=CFG.weight_decay, amsgrad=False)
    scheduler = get_scheduler(optimizer)

    # ====================================================
    # loop
    # ====================================================
    criterion = RMSELoss()

    best_score = np.inf
    best_loss = np.inf
    
    for epoch in range(CFG.epochs):
        
        start_time = time.time()
        
        # train
        avg_loss = train_fn(fold, train_loader, model, criterion, optimizer, epoch, scheduler, device)

        # eval
        avg_val_loss, preds = valid_fn(valid_loader, model, criterion, device)
        
        if isinstance(scheduler, ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        elif isinstance(scheduler, CosineAnnealingLR):
            scheduler.step()
        elif isinstance(scheduler, CosineAnnealingWarmRestarts):
            scheduler.step()

        # scoring
        score = get_score(valid_labels, preds)

        elapsed = time.time() - start_time

        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s')
        LOGGER.info(f'Epoch {epoch+1} - Score: {score:.4f}')
       
        if score < best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'model': model.state_dict(), 'preds': preds}, OUTPUT_DIR+f'{CFG.model_name}_{CFG.kfold}_fold{fold}_seed{seed}_bootstrap.pth')
    
    valid_folds['preds'] = torch.load(OUTPUT_DIR+f'{CFG.model_name}_{CFG.kfold}_fold{fold}_seed{seed}_bootstrap.pth', 
                                      map_location=torch.device('cpu'))['preds']

    return valid_folds

# %%
# ====================================================
# main
# ====================================================
def main():

    """
    Prepare: 1.train 
    """

    def get_result(result_df):
        preds = result_df['preds'].values
        labels = result_df[CFG.target_col].values
        score = get_score(labels, preds)
        LOGGER.info(f'Score: {score:<.4f}')
    
    for seed in CFG.seed:
        LOGGER.info(f"========== seed{seed} ==========")
        seed_torch()

        data = pd.read_csv('./Mototake_Analysis/VGG+GP/inout_data.csv', header=None, names=['Id', 'KIc'])
        data['file_path'] = ['./Mototake_Analysis/VGG+GP/imagedata/' + str(i) + '.jpg' for i in data['Id']]

        train = pd.DataFrame()
        data_id = np.random.choice(data['Id'], size=len(data), replace=True)
        for i in data_id:
            train = pd.concat([train, data[data['Id']==i]])
        train = train.reset_index()
            
        if CFG.debug:
            CFG.epochs = 1
            train = train.sample(n=100, random_state=seed).reset_index(drop=True)


        if CFG.kfold == 'Kfold':
            Fold = KFold(n_splits=CFG.n_fold, shuffle=True, random_state=seed)
            for n, (train_index, val_index) in enumerate(Fold.split(train)):
                train.loc[val_index, 'fold'] = int(n)
            train['fold'] = train['fold'].astype(int)
        elif CFG.kfold == "StratifiedKfold":
            num_bins = int(np.floor(1 + np.log2(len(train))))
            train["bins"] = pd.cut(train[CFG.target_col], bins=num_bins, labels=False)
            Fold = StratifiedKFold(n_splits=CFG.n_fold, shuffle=True, random_state=seed)
            for n, (train_index, val_index) in enumerate(Fold.split(train, train["bins"])):
                train.loc[val_index, 'fold'] = int(n)
            train['fold'] = train['fold'].astype(int)

        # # train出力 vgg 
        oof_df = pd.DataFrame()
        for fold in range(CFG.n_fold):
            # train.to_csv vggも
            _oof_df = train_loop(train, fold, seed)
            oof_df = pd.concat([oof_df, _oof_df])
            LOGGER.info(f"========== fold: {fold} result ==========")
            get_result(_oof_df)

        # CV result
        LOGGER.info(f"========== CV ==========")
        get_result(oof_df)

        # save result
        oof_df.to_csv(OUTPUT_DIR+f'{CFG.model_name}_{CFG.kfold}_seed{seed}_bootstrap_trainaug_oof_df.csv', index=False)

# %%
if __name__ == '__main__':
    main()
# Out:
# ========== seed42 ==========
# ========== fold: 0 training ==========
# Epoch: [1][0/19] Elapsed 0m 1s (remain 0m 31s) Loss: 3.5101(3.5101) Grad: 3.3239  LR: 0.000100
# Epoch: [1][10/19] Elapsed 0m 4s (remain 0m 3s) Loss: 0.7402(1.6345) Grad: 3.3044  LR: 0.000100
# Epoch: [1][18/19] Elapsed 0m 7s (remain 0m 0s) Loss: 0.5414(1.2297) Grad: 1.2775  LR: 0.000100
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.6510(0.6510)
# Epoch 1 - avg_train_loss: 1.2297  avg_val_loss: 0.6218  time: 8s
# Epoch 1 - Score: 0.6223
# Epoch 1 - Save Best Score: 0.6223 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.6078(0.6218)
# Epoch: [2][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.6528(0.6528) Grad: 3.0171  LR: 0.000057
# Epoch: [2][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.6341(0.6096) Grad: 1.0611  LR: 0.000057
# Epoch: [2][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.7329(0.5933) Grad: 3.0844  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5711(0.5711)
# Epoch 2 - avg_train_loss: 0.5933  avg_val_loss: 0.5317  time: 7s
# Epoch 2 - Score: 0.5327
# Epoch 2 - Save Best Score: 0.5327 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4924(0.5317)
# Epoch: [3][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5092(0.5092) Grad: 1.0127  LR: 0.000009
# Epoch: [3][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4053(0.4946) Grad: 1.0440  LR: 0.000009
# Epoch: [3][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.4661(0.4988) Grad: 1.0548  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5308(0.5308)
# Epoch 3 - avg_train_loss: 0.4988  avg_val_loss: 0.4903  time: 7s
# Epoch 3 - Score: 0.4916
# Epoch 3 - Save Best Score: 0.4916 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4445(0.4903)
# Epoch: [4][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4206(0.4206) Grad: 1.1204  LR: 0.000001
# Epoch: [4][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.5469(0.4336) Grad: 1.7808  LR: 0.000001
# Epoch: [4][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.6308(0.4467) Grad: 2.2829  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5122(0.5122)
# Epoch 4 - avg_train_loss: 0.4467  avg_val_loss: 0.4731  time: 7s
# Epoch 4 - Score: 0.4743
# Epoch 4 - Save Best Score: 0.4743 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4468(0.4731)
# Epoch: [5][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3939(0.3939) Grad: 1.8025  LR: 0.000050
# Epoch: [5][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4355(0.4304) Grad: 1.9949  LR: 0.000050
# Epoch: [5][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.4168(0.4190) Grad: 1.7628  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4505(0.4505)
# Epoch 5 - avg_train_loss: 0.4190  avg_val_loss: 0.4169  time: 7s
# Epoch 5 - Score: 0.4184
# Epoch 5 - Save Best Score: 0.4184 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4397(0.4169)
# Epoch: [6][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4451(0.4451) Grad: 4.6652  LR: 0.000224
# Epoch: [6][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3451(0.3995) Grad: 1.9679  LR: 0.000224
# Epoch: [6][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2946(0.3883) Grad: 2.2401  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4664(0.4664)
# Epoch 6 - avg_train_loss: 0.3883  avg_val_loss: 0.4071  time: 7s
# Epoch 6 - Score: 0.4103
# Epoch 6 - Save Best Score: 0.4103 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3845(0.4071)
# Epoch: [7][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3219(0.3219) Grad: 1.9797  LR: 0.000133
# Epoch: [7][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3759(0.3369) Grad: 1.9012  LR: 0.000133
# Epoch: [7][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2747(0.3379) Grad: 0.5987  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3387(0.3387)
# Epoch 7 - avg_train_loss: 0.3379  avg_val_loss: 0.3156  time: 7s
# Epoch 7 - Score: 0.3166
# Epoch 7 - Save Best Score: 0.3166 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3326(0.3156)
# Epoch: [8][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2276(0.2276) Grad: 1.8269  LR: 0.000057
# Epoch: [8][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3653(0.2949) Grad: 3.3613  LR: 0.000057
# Epoch: [8][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2283(0.2886) Grad: 3.0104  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2933(0.2933)
# Epoch 8 - avg_train_loss: 0.2886  avg_val_loss: 0.2696  time: 7s
# Epoch 8 - Score: 0.2707
# Epoch 8 - Save Best Score: 0.2707 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2816(0.2696)
# Epoch: [9][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2076(0.2076) Grad: 1.5892  LR: 0.000009
# Epoch: [9][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2432(0.2430) Grad: 2.7897  LR: 0.000009
# Epoch: [9][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2576(0.2567) Grad: 2.0241  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2938(0.2938)
# Epoch 9 - avg_train_loss: 0.2567  avg_val_loss: 0.2627  time: 7s
# Epoch 9 - Score: 0.2642
# Epoch 9 - Save Best Score: 0.2642 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2626(0.2627)
# Epoch: [10][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1788(0.1788) Grad: 3.0561  LR: 0.000001
# Epoch: [10][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1851(0.2457) Grad: 2.5119  LR: 0.000001
# Epoch: [10][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2476(0.2348) Grad: 0.9483  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2937(0.2937)
# Epoch 10 - avg_train_loss: 0.2348  avg_val_loss: 0.2557  time: 7s
# Epoch 10 - Score: 0.2579
# Epoch 10 - Save Best Score: 0.2579 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2481(0.2557)
# Epoch: [11][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2330(0.2330) Grad: 0.6031  LR: 0.000050
# Epoch: [11][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1860(0.2362) Grad: 0.7178  LR: 0.000050
# Epoch: [11][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2046(0.2330) Grad: 1.3592  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2809(0.2809)
# Epoch 11 - avg_train_loss: 0.2330  avg_val_loss: 0.2432  time: 7s
# Epoch 11 - Score: 0.2453
# Epoch 11 - Save Best Score: 0.2453 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2135(0.2432)
# Epoch: [12][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1724(0.1724) Grad: 1.1050  LR: 0.000224
# Epoch: [12][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2025(0.2423) Grad: 1.7193  LR: 0.000224
# Epoch: [12][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2335(0.2318) Grad: 2.2462  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2690(0.2690)
# Epoch 12 - avg_train_loss: 0.2318  avg_val_loss: 0.2389  time: 7s
# Epoch 12 - Score: 0.2407
# Epoch 12 - Save Best Score: 0.2407 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1873(0.2389)
# Epoch: [13][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1232(0.1232) Grad: 0.8077  LR: 0.000133
# Epoch: [13][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2611(0.2001) Grad: 2.0432  LR: 0.000133
# Epoch: [13][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2773(0.2220) Grad: 2.7700  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2697(0.2697)
# Epoch 13 - avg_train_loss: 0.2220  avg_val_loss: 0.2281  time: 7s
# Epoch 13 - Score: 0.2319
# Epoch 13 - Save Best Score: 0.2319 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1528(0.2281)
# Epoch: [14][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2504(0.2504) Grad: 0.9142  LR: 0.000057
# Epoch: [14][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2063(0.2018) Grad: 4.6372  LR: 0.000057
# Epoch: [14][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2340(0.2133) Grad: 0.7834  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2827(0.2827)
# Epoch 14 - avg_train_loss: 0.2133  avg_val_loss: 0.2271  time: 7s
# Epoch 14 - Score: 0.2319
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1788(0.2271)
# Epoch: [15][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1978(0.1978) Grad: 2.4189  LR: 0.000009
# Epoch: [15][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2079(0.1735) Grad: 2.1826  LR: 0.000009
# Epoch: [15][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1450(0.1678) Grad: 0.9181  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2654(0.2654)
# Epoch 15 - avg_train_loss: 0.1678  avg_val_loss: 0.2171  time: 7s
# Epoch 15 - Score: 0.2210
# Epoch 15 - Save Best Score: 0.2210 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1737(0.2171)
# Epoch: [16][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1666(0.1666) Grad: 1.5550  LR: 0.000001
# Epoch: [16][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2060(0.1472) Grad: 0.7095  LR: 0.000001
# Epoch: [16][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1466(0.1447) Grad: 1.9698  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2622(0.2622)
# Epoch 16 - avg_train_loss: 0.1447  avg_val_loss: 0.2138  time: 7s
# Epoch 16 - Score: 0.2177
# Epoch 16 - Save Best Score: 0.2177 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1707(0.2138)
# Epoch: [17][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1767(0.1767) Grad: 1.5937  LR: 0.000050
# Epoch: [17][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1520(0.1521) Grad: 1.7770  LR: 0.000050
# Epoch: [17][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1238(0.1408) Grad: 0.8730  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2569(0.2569)
# Epoch 17 - avg_train_loss: 0.1408  avg_val_loss: 0.2101  time: 7s
# Epoch 17 - Score: 0.2138
# Epoch 17 - Save Best Score: 0.2138 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1637(0.2101)
# Epoch: [18][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2395(0.2395) Grad: 1.9630  LR: 0.000224
# Epoch: [18][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0940(0.1456) Grad: 2.1844  LR: 0.000224
# Epoch: [18][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1534(0.1418) Grad: 4.0115  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2553(0.2553)
# Epoch 18 - avg_train_loss: 0.1418  avg_val_loss: 0.2194  time: 7s
# Epoch 18 - Score: 0.2215
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1889(0.2194)
# Epoch: [19][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1640(0.1640) Grad: 1.0568  LR: 0.000133
# Epoch: [19][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1635(0.1577) Grad: 1.5664  LR: 0.000133
# Epoch: [19][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1596(0.1688) Grad: 1.2733  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3125(0.3125)
# Epoch 19 - avg_train_loss: 0.1688  avg_val_loss: 0.2684  time: 7s
# Epoch 19 - Score: 0.2711
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2195(0.2684)
# Epoch: [20][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1182(0.1182) Grad: 3.2704  LR: 0.000057
# Epoch: [20][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1817(0.1602) Grad: 2.7494  LR: 0.000057
# Epoch: [20][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1344(0.1627) Grad: 2.3794  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2811(0.2811)
# Epoch 20 - avg_train_loss: 0.1627  avg_val_loss: 0.2372  time: 7s
# Epoch 20 - Score: 0.2401
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1971(0.2372)
# Epoch: [21][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1680(0.1680) Grad: 3.7265  LR: 0.000009
# Epoch: [21][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1704(0.1457) Grad: 3.4509  LR: 0.000009
# Epoch: [21][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0897(0.1319) Grad: 1.4019  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2605(0.2605)
# Epoch 21 - avg_train_loss: 0.1319  avg_val_loss: 0.2132  time: 7s
# Epoch 21 - Score: 0.2170
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1661(0.2132)
# Epoch: [22][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0998(0.0998) Grad: 0.9627  LR: 0.000001
# Epoch: [22][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0883(0.1012) Grad: 3.1136  LR: 0.000001
# Epoch: [22][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1142(0.1051) Grad: 0.8749  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2562(0.2562)
# Epoch 22 - avg_train_loss: 0.1051  avg_val_loss: 0.2040  time: 7s
# Epoch 22 - Score: 0.2090
# Epoch 22 - Save Best Score: 0.2090 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1457(0.2040)
# Epoch: [23][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0781(0.0781) Grad: 2.9261  LR: 0.000050
# Epoch: [23][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1224(0.1231) Grad: 0.5963  LR: 0.000050
# Epoch: [23][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1439(0.1168) Grad: 1.1505  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2571(0.2571)
# Epoch 23 - avg_train_loss: 0.1168  avg_val_loss: 0.2028  time: 7s
# Epoch 23 - Score: 0.2085
# Epoch 23 - Save Best Score: 0.2085 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1334(0.2028)
# Epoch: [24][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0861(0.0861) Grad: 0.7470  LR: 0.000224
# Epoch: [24][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1327(0.1092) Grad: 1.9739  LR: 0.000224
# Epoch: [24][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1223(0.1071) Grad: 3.4216  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2740(0.2740)
# Epoch 24 - avg_train_loss: 0.1071  avg_val_loss: 0.2193  time: 7s
# Epoch 24 - Score: 0.2245
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1538(0.2193)
# Epoch: [25][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1116(0.1116) Grad: 1.2974  LR: 0.000133
# Epoch: [25][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1085(0.1164) Grad: 1.2476  LR: 0.000133
# Epoch: [25][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1431(0.1223) Grad: 4.2855  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2702(0.2702)
# Epoch 25 - avg_train_loss: 0.1223  avg_val_loss: 0.2174  time: 7s
# Epoch 25 - Score: 0.2222
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1577(0.2174)
# Epoch: [26][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0925(0.0925) Grad: 1.0165  LR: 0.000057
# Epoch: [26][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0784(0.1121) Grad: 0.8360  LR: 0.000057
# Epoch: [26][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0911(0.1093) Grad: 2.6131  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2604(0.2604)
# Epoch 26 - avg_train_loss: 0.1093  avg_val_loss: 0.2120  time: 7s
# Epoch 26 - Score: 0.2165
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1435(0.2120)
# Epoch: [27][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0924(0.0924) Grad: 1.5388  LR: 0.000009
# Epoch: [27][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0937(0.0935) Grad: 3.2194  LR: 0.000009
# Epoch: [27][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0773(0.0878) Grad: 2.3568  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2579(0.2579)
# Epoch 27 - avg_train_loss: 0.0878  avg_val_loss: 0.2036  time: 7s
# Epoch 27 - Score: 0.2091
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1364(0.2036)
# Epoch: [28][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0585(0.0585) Grad: 1.9414  LR: 0.000001
# Epoch: [28][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0750(0.0785) Grad: 0.6539  LR: 0.000001
# Epoch: [28][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0712(0.0746) Grad: 0.6364  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2560(0.2560)
# Epoch 28 - avg_train_loss: 0.0746  avg_val_loss: 0.2022  time: 7s
# Epoch 28 - Score: 0.2076
# Epoch 28 - Save Best Score: 0.2076 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1368(0.2022)
# Epoch: [29][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0721(0.0721) Grad: 1.8175  LR: 0.000050
# Epoch: [29][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0668(0.0682) Grad: 1.3269  LR: 0.000050
# Epoch: [29][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0717(0.0744) Grad: 1.4305  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2501(0.2501)
# Epoch 29 - avg_train_loss: 0.0744  avg_val_loss: 0.2010  time: 7s
# Epoch 29 - Score: 0.2057
# Epoch 29 - Save Best Score: 0.2057 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1361(0.2010)
# Epoch: [30][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0432(0.0432) Grad: 1.3908  LR: 0.000224
# Epoch: [30][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0613(0.0793) Grad: 2.1590  LR: 0.000224
# Epoch: [30][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0878(0.0805) Grad: 0.7678  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2519(0.2519)
# Epoch 30 - avg_train_loss: 0.0805  avg_val_loss: 0.2056  time: 7s
# Epoch 30 - Score: 0.2102
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1340(0.2056)
# Epoch: [31][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0882(0.0882) Grad: 1.2529  LR: 0.000133
# Epoch: [31][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1231(0.0906) Grad: 4.7464  LR: 0.000133
# Epoch: [31][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0874(0.0959) Grad: 1.1222  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2890(0.2890)
# Epoch 31 - avg_train_loss: 0.0959  avg_val_loss: 0.2328  time: 7s
# Epoch 31 - Score: 0.2386
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1475(0.2328)
# Epoch: [32][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1275(0.1275) Grad: 4.5558  LR: 0.000057
# Epoch: [32][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0909(0.1141) Grad: 0.9471  LR: 0.000057
# Epoch: [32][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1068(0.1071) Grad: 1.7832  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2656(0.2656)
# Epoch 32 - avg_train_loss: 0.1071  avg_val_loss: 0.2222  time: 7s
# Epoch 32 - Score: 0.2264
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1434(0.2222)
# Epoch: [33][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1092(0.1092) Grad: 3.3337  LR: 0.000009
# Epoch: [33][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0758(0.0864) Grad: 1.2976  LR: 0.000009
# Epoch: [33][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0495(0.0779) Grad: 0.6464  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2512(0.2512)
# Epoch 33 - avg_train_loss: 0.0779  avg_val_loss: 0.2026  time: 7s
# Epoch 33 - Score: 0.2078
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1246(0.2026)
# Epoch: [34][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0812(0.0812) Grad: 3.3906  LR: 0.000001
# Epoch: [34][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0658(0.0707) Grad: 0.5662  LR: 0.000001
# Epoch: [34][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0575(0.0655) Grad: 1.1583  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2499(0.2499)
# Epoch 34 - avg_train_loss: 0.0655  avg_val_loss: 0.1991  time: 7s
# Epoch 34 - Score: 0.2046
# Epoch 34 - Save Best Score: 0.2046 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1228(0.1991)
# Epoch: [35][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0501(0.0501) Grad: 1.2673  LR: 0.000050
# Epoch: [35][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0739(0.0656) Grad: 0.5660  LR: 0.000050
# Epoch: [35][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0410(0.0602) Grad: 1.1038  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2601(0.2601)
# Epoch 35 - avg_train_loss: 0.0602  avg_val_loss: 0.2028  time: 7s
# Epoch 35 - Score: 0.2094
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1219(0.2028)
# Epoch: [36][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0681(0.0681) Grad: 0.9922  LR: 0.000224
# Epoch: [36][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0610(0.0587) Grad: 1.4091  LR: 0.000224
# Epoch: [36][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0607(0.0632) Grad: 2.0167  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2560(0.2560)
# Epoch 36 - avg_train_loss: 0.0632  avg_val_loss: 0.2062  time: 7s
# Epoch 36 - Score: 0.2118
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1214(0.2062)
# Epoch: [37][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0575(0.0575) Grad: 0.9009  LR: 0.000133
# Epoch: [37][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0973(0.0778) Grad: 3.2455  LR: 0.000133
# Epoch: [37][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1244(0.0873) Grad: 4.6674  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2448(0.2448)
# Epoch 37 - avg_train_loss: 0.0873  avg_val_loss: 0.2041  time: 7s
# Epoch 37 - Score: 0.2085
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1237(0.2041)
# Epoch: [38][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0962(0.0962) Grad: 3.2645  LR: 0.000057
# Epoch: [38][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0833(0.0875) Grad: 3.0295  LR: 0.000057
# Epoch: [38][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0849(0.0863) Grad: 1.2449  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2555(0.2555)
# Epoch 38 - avg_train_loss: 0.0863  avg_val_loss: 0.2074  time: 7s
# Epoch 38 - Score: 0.2118
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1459(0.2074)
# Epoch: [39][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0689(0.0689) Grad: 1.2467  LR: 0.000009
# Epoch: [39][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0538(0.0580) Grad: 0.4468  LR: 0.000009
# Epoch: [39][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0850(0.0603) Grad: 0.8434  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2526(0.2526)
# Epoch 39 - avg_train_loss: 0.0603  avg_val_loss: 0.1995  time: 7s
# Epoch 39 - Score: 0.2056
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1167(0.1995)
# Epoch: [40][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0412(0.0412) Grad: 1.5932  LR: 0.000001
# Epoch: [40][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0653(0.0596) Grad: 0.8139  LR: 0.000001
# Epoch: [40][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0467(0.0577) Grad: 0.4952  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2505(0.2505)
# Epoch 40 - avg_train_loss: 0.0577  avg_val_loss: 0.1975  time: 7s
# Epoch 40 - Score: 0.2035
# Epoch 40 - Save Best Score: 0.2035 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1180(0.1975)
# ========== fold: 0 result ==========
# Score: 0.2035
# ========== fold: 1 training ==========
# Epoch: [1][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 3.2565(3.2565) Grad: 3.4204  LR: 0.000100
# Epoch: [1][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.7371(1.5587) Grad: 4.3154  LR: 0.000100
# Epoch: [1][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.6203(1.1867) Grad: 0.3835  LR: 0.000100
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.6797(0.6797)
# Epoch 1 - avg_train_loss: 1.1867  avg_val_loss: 0.6096  time: 7s
# Epoch 1 - Score: 0.6125
# Epoch 1 - Save Best Score: 0.6125 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5498(0.6096)
# Epoch: [2][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.7147(0.7147) Grad: 0.7770  LR: 0.000057
# Epoch: [2][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.5935(0.6166) Grad: 1.6229  LR: 0.000057
# Epoch: [2][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.4240(0.5885) Grad: 3.7434  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5681(0.5681)
# Epoch 2 - avg_train_loss: 0.5885  avg_val_loss: 0.5123  time: 7s
# Epoch 2 - Score: 0.5152
# Epoch 2 - Save Best Score: 0.5152 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5271(0.5123)
# Epoch: [3][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4382(0.4382) Grad: 2.1032  LR: 0.000009
# Epoch: [3][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4830(0.4743) Grad: 1.7777  LR: 0.000009
# Epoch: [3][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3707(0.4680) Grad: 1.0808  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5335(0.5335)
# Epoch 3 - avg_train_loss: 0.4680  avg_val_loss: 0.4708  time: 7s
# Epoch 3 - Score: 0.4740
# Epoch 3 - Save Best Score: 0.4740 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4568(0.4708)
# Epoch: [4][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5383(0.5383) Grad: 1.4574  LR: 0.000001
# Epoch: [4][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4876(0.4214) Grad: 3.1694  LR: 0.000001
# Epoch: [4][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3466(0.4168) Grad: 0.7231  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4905(0.4905)
# Epoch 4 - avg_train_loss: 0.4168  avg_val_loss: 0.4406  time: 7s
# Epoch 4 - Score: 0.4432
# Epoch 4 - Save Best Score: 0.4432 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4505(0.4406)
# Epoch: [5][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2742(0.2742) Grad: 0.7152  LR: 0.000050
# Epoch: [5][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4013(0.4079) Grad: 2.1999  LR: 0.000050
# Epoch: [5][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.4036(0.4095) Grad: 1.6543  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4691(0.4691)
# Epoch 5 - avg_train_loss: 0.4095  avg_val_loss: 0.4173  time: 7s
# Epoch 5 - Score: 0.4202
# Epoch 5 - Save Best Score: 0.4202 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4259(0.4173)
# Epoch: [6][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3729(0.3729) Grad: 1.0504  LR: 0.000224
# Epoch: [6][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4231(0.3834) Grad: 1.4336  LR: 0.000224
# Epoch: [6][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2263(0.3744) Grad: 1.0116  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4302(0.4302)
# Epoch 6 - avg_train_loss: 0.3744  avg_val_loss: 0.3868  time: 7s
# Epoch 6 - Score: 0.3885
# Epoch 6 - Save Best Score: 0.3885 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3601(0.3868)
# Epoch: [7][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2988(0.2988) Grad: 0.7738  LR: 0.000133
# Epoch: [7][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3987(0.3427) Grad: 0.3903  LR: 0.000133
# Epoch: [7][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3959(0.3416) Grad: 1.0169  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3670(0.3670)
# Epoch 7 - avg_train_loss: 0.3416  avg_val_loss: 0.3379  time: 7s
# Epoch 7 - Score: 0.3389
# Epoch 7 - Save Best Score: 0.3389 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3048(0.3379)
# Epoch: [8][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.3025(0.3025) Grad: 0.9831  LR: 0.000057
# Epoch: [8][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4084(0.3095) Grad: 1.1997  LR: 0.000057
# Epoch: [8][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2452(0.3056) Grad: 2.6807  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3231(0.3231)
# Epoch 8 - avg_train_loss: 0.3056  avg_val_loss: 0.3404  time: 7s
# Epoch 8 - Score: 0.3407
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3395(0.3404)
# Epoch: [9][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3541(0.3541) Grad: 4.1478  LR: 0.000009
# Epoch: [9][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2819(0.2768) Grad: 1.8078  LR: 0.000009
# Epoch: [9][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2294(0.2619) Grad: 0.9023  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2898(0.2898)
# Epoch 9 - avg_train_loss: 0.2619  avg_val_loss: 0.3015  time: 7s
# Epoch 9 - Score: 0.3027
# Epoch 9 - Save Best Score: 0.3027 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2600(0.3015)
# Epoch: [10][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1967(0.1967) Grad: 1.2880  LR: 0.000001
# Epoch: [10][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2396(0.2312) Grad: 1.4884  LR: 0.000001
# Epoch: [10][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3214(0.2398) Grad: 1.4947  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2862(0.2862)
# Epoch 10 - avg_train_loss: 0.2398  avg_val_loss: 0.2986  time: 7s
# Epoch 10 - Score: 0.2997
# Epoch 10 - Save Best Score: 0.2997 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2592(0.2986)
# Epoch: [11][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1887(0.1887) Grad: 0.9583  LR: 0.000050
# Epoch: [11][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1222(0.2261) Grad: 0.6189  LR: 0.000050
# Epoch: [11][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2611(0.2286) Grad: 0.8662  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2740(0.2740)
# Epoch 11 - avg_train_loss: 0.2286  avg_val_loss: 0.2894  time: 7s
# Epoch 11 - Score: 0.2912
# Epoch 11 - Save Best Score: 0.2912 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2401(0.2894)
# Epoch: [12][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2383(0.2383) Grad: 0.7335  LR: 0.000224
# Epoch: [12][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1989(0.2321) Grad: 0.7460  LR: 0.000224
# Epoch: [12][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2622(0.2216) Grad: 1.2390  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2661(0.2661)
# Epoch 12 - avg_train_loss: 0.2216  avg_val_loss: 0.2950  time: 7s
# Epoch 12 - Score: 0.2962
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2953(0.2950)
# Epoch: [13][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2342(0.2342) Grad: 1.9831  LR: 0.000133
# Epoch: [13][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2490(0.2617) Grad: 2.7242  LR: 0.000133
# Epoch: [13][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2004(0.2512) Grad: 2.2968  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2488(0.2488)
# Epoch 13 - avg_train_loss: 0.2512  avg_val_loss: 0.2638  time: 7s
# Epoch 13 - Score: 0.2646
# Epoch 13 - Save Best Score: 0.2646 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2414(0.2638)
# Epoch: [14][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3256(0.3256) Grad: 1.6125  LR: 0.000057
# Epoch: [14][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1819(0.2490) Grad: 0.5802  LR: 0.000057
# Epoch: [14][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2024(0.2285) Grad: 2.6394  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2468(0.2468)
# Epoch 14 - avg_train_loss: 0.2285  avg_val_loss: 0.2583  time: 7s
# Epoch 14 - Score: 0.2591
# Epoch 14 - Save Best Score: 0.2591 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2287(0.2583)
# Epoch: [15][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2084(0.2084) Grad: 2.3128  LR: 0.000009
# Epoch: [15][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1790(0.1937) Grad: 0.8767  LR: 0.000009
# Epoch: [15][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1538(0.1846) Grad: 2.6482  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2165(0.2165)
# Epoch 15 - avg_train_loss: 0.1846  avg_val_loss: 0.2472  time: 7s
# Epoch 15 - Score: 0.2494
# Epoch 15 - Save Best Score: 0.2494 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2279(0.2472)
# Epoch: [16][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2232(0.2232) Grad: 1.9530  LR: 0.000001
# Epoch: [16][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2101(0.1673) Grad: 2.3304  LR: 0.000001
# Epoch: [16][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1890(0.1595) Grad: 1.9553  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2165(0.2165)
# Epoch 16 - avg_train_loss: 0.1595  avg_val_loss: 0.2409  time: 7s
# Epoch 16 - Score: 0.2427
# Epoch 16 - Save Best Score: 0.2427 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2168(0.2409)
# Epoch: [17][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1885(0.1885) Grad: 1.6558  LR: 0.000050
# Epoch: [17][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1780(0.1733) Grad: 3.0608  LR: 0.000050
# Epoch: [17][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1633(0.1684) Grad: 2.0442  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2136(0.2136)
# Epoch 17 - avg_train_loss: 0.1684  avg_val_loss: 0.2500  time: 7s
# Epoch 17 - Score: 0.2529
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2293(0.2500)
# Epoch: [18][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1601(0.1601) Grad: 4.2307  LR: 0.000224
# Epoch: [18][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1343(0.1423) Grad: 2.3824  LR: 0.000224
# Epoch: [18][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1706(0.1533) Grad: 3.8022  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2209(0.2209)
# Epoch 18 - avg_train_loss: 0.1533  avg_val_loss: 0.2486  time: 7s
# Epoch 18 - Score: 0.2505
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2265(0.2486)
# Epoch: [19][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1565(0.1565) Grad: 2.2600  LR: 0.000133
# Epoch: [19][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0900(0.1462) Grad: 0.5922  LR: 0.000133
# Epoch: [19][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1790(0.1543) Grad: 2.5875  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2061(0.2061)
# Epoch 19 - avg_train_loss: 0.1543  avg_val_loss: 0.2567  time: 7s
# Epoch 19 - Score: 0.2603
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2818(0.2567)
# Epoch: [20][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1308(0.1308) Grad: 2.7926  LR: 0.000057
# Epoch: [20][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1116(0.1520) Grad: 1.1389  LR: 0.000057
# Epoch: [20][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1104(0.1444) Grad: 1.0412  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1889(0.1889)
# Epoch 20 - avg_train_loss: 0.1444  avg_val_loss: 0.2519  time: 7s
# Epoch 20 - Score: 0.2579
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2649(0.2519)
# Epoch: [21][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1569(0.1569) Grad: 3.2637  LR: 0.000009
# Epoch: [21][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1307(0.1336) Grad: 1.5954  LR: 0.000009
# Epoch: [21][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1736(0.1271) Grad: 2.1142  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1782(0.1782)
# Epoch 21 - avg_train_loss: 0.1271  avg_val_loss: 0.2275  time: 7s
# Epoch 21 - Score: 0.2324
# Epoch 21 - Save Best Score: 0.2324 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2164(0.2275)
# Epoch: [22][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1328(0.1328) Grad: 3.7566  LR: 0.000001
# Epoch: [22][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0676(0.1066) Grad: 3.0205  LR: 0.000001
# Epoch: [22][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0842(0.1158) Grad: 0.5437  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1608(0.1608)
# Epoch 22 - avg_train_loss: 0.1158  avg_val_loss: 0.2040  time: 7s
# Epoch 22 - Score: 0.2084
# Epoch 22 - Save Best Score: 0.2084 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1883(0.2040)
# Epoch: [23][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1226(0.1226) Grad: 1.3317  LR: 0.000050
# Epoch: [23][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1270(0.1477) Grad: 4.4106  LR: 0.000050
# Epoch: [23][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1385(0.1334) Grad: 2.3787  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1651(0.1651)
# Epoch 23 - avg_train_loss: 0.1334  avg_val_loss: 0.2119  time: 7s
# Epoch 23 - Score: 0.2161
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2110(0.2119)
# Epoch: [24][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1091(0.1091) Grad: 2.8133  LR: 0.000224
# Epoch: [24][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1045(0.1266) Grad: 1.1662  LR: 0.000224
# Epoch: [24][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0929(0.1183) Grad: 0.7126  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1600(0.1600)
# Epoch 24 - avg_train_loss: 0.1183  avg_val_loss: 0.2096  time: 7s
# Epoch 24 - Score: 0.2138
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2303(0.2096)
# Epoch: [25][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1025(0.1025) Grad: 0.6744  LR: 0.000133
# Epoch: [25][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1195(0.1220) Grad: 1.3271  LR: 0.000133
# Epoch: [25][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1057(0.1340) Grad: 2.2513  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1927(0.1927)
# Epoch 25 - avg_train_loss: 0.1340  avg_val_loss: 0.2180  time: 7s
# Epoch 25 - Score: 0.2192
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2150(0.2180)
# Epoch: [26][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1688(0.1688) Grad: 2.8271  LR: 0.000057
# Epoch: [26][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0792(0.1250) Grad: 2.3839  LR: 0.000057
# Epoch: [26][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1353(0.1253) Grad: 1.5056  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1738(0.1738)
# Epoch 26 - avg_train_loss: 0.1253  avg_val_loss: 0.2200  time: 7s
# Epoch 26 - Score: 0.2245
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2087(0.2200)
# Epoch: [27][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1100(0.1100) Grad: 3.2999  LR: 0.000009
# Epoch: [27][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0877(0.1046) Grad: 2.9420  LR: 0.000009
# Epoch: [27][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1127(0.1019) Grad: 1.3561  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1359(0.1359)
# Epoch 27 - avg_train_loss: 0.1019  avg_val_loss: 0.1895  time: 7s
# Epoch 27 - Score: 0.1954
# Epoch 27 - Save Best Score: 0.1954 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1940(0.1895)
# Epoch: [28][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0598(0.0598) Grad: 0.6760  LR: 0.000001
# Epoch: [28][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0582(0.0830) Grad: 1.7320  LR: 0.000001
# Epoch: [28][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0678(0.0877) Grad: 1.5391  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1337(0.1337)
# Epoch 28 - avg_train_loss: 0.0877  avg_val_loss: 0.1903  time: 7s
# Epoch 28 - Score: 0.1970
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1963(0.1903)
# Epoch: [29][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1141(0.1141) Grad: 0.8334  LR: 0.000050
# Epoch: [29][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0948(0.0947) Grad: 0.9776  LR: 0.000050
# Epoch: [29][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0541(0.0864) Grad: 1.9973  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1290(0.1290)
# Epoch 29 - avg_train_loss: 0.0864  avg_val_loss: 0.1915  time: 7s
# Epoch 29 - Score: 0.1999
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1910(0.1915)
# Epoch: [30][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0766(0.0766) Grad: 2.4395  LR: 0.000224
# Epoch: [30][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0904(0.0919) Grad: 4.1155  LR: 0.000224
# Epoch: [30][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0766(0.0963) Grad: 2.2056  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1346(0.1346)
# Epoch 30 - avg_train_loss: 0.0963  avg_val_loss: 0.2086  time: 7s
# Epoch 30 - Score: 0.2183
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2292(0.2086)
# Epoch: [31][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0865(0.0865) Grad: 3.7458  LR: 0.000133
# Epoch: [31][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1008(0.1056) Grad: 2.8082  LR: 0.000133
# Epoch: [31][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0882(0.1059) Grad: 0.5131  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1503(0.1503)
# Epoch 31 - avg_train_loss: 0.1059  avg_val_loss: 0.1934  time: 7s
# Epoch 31 - Score: 0.1971
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2016(0.1934)
# Epoch: [32][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1284(0.1284) Grad: 2.8504  LR: 0.000057
# Epoch: [32][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1368(0.1060) Grad: 2.0682  LR: 0.000057
# Epoch: [32][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0686(0.0972) Grad: 2.4316  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1373(0.1373)
# Epoch 32 - avg_train_loss: 0.0972  avg_val_loss: 0.2022  time: 7s
# Epoch 32 - Score: 0.2104
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2089(0.2022)
# Epoch: [33][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0983(0.0983) Grad: 1.9111  LR: 0.000009
# Epoch: [33][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0808(0.0803) Grad: 1.4352  LR: 0.000009
# Epoch: [33][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0823(0.0841) Grad: 3.2135  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1111(0.1111)
# Epoch 33 - avg_train_loss: 0.0841  avg_val_loss: 0.1754  time: 7s
# Epoch 33 - Score: 0.1844
# Epoch 33 - Save Best Score: 0.1844 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1869(0.1754)
# Epoch: [34][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0446(0.0446) Grad: 0.7446  LR: 0.000001
# Epoch: [34][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0439(0.0668) Grad: 0.9383  LR: 0.000001
# Epoch: [34][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0701(0.0728) Grad: 1.1870  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1104(0.1104)
# Epoch 34 - avg_train_loss: 0.0728  avg_val_loss: 0.1760  time: 7s
# Epoch 34 - Score: 0.1853
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1861(0.1760)
# Epoch: [35][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0523(0.0523) Grad: 0.8830  LR: 0.000050
# Epoch: [35][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0712(0.0650) Grad: 0.5685  LR: 0.000050
# Epoch: [35][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0551(0.0698) Grad: 0.7944  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1065(0.1065)
# Epoch 35 - avg_train_loss: 0.0698  avg_val_loss: 0.1765  time: 7s
# Epoch 35 - Score: 0.1873
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1837(0.1765)
# Epoch: [36][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0395(0.0395) Grad: 2.0240  LR: 0.000224
# Epoch: [36][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0590(0.0681) Grad: 3.2581  LR: 0.000224
# Epoch: [36][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0557(0.0723) Grad: 0.5072  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1124(0.1124)
# Epoch 36 - avg_train_loss: 0.0723  avg_val_loss: 0.1875  time: 7s
# Epoch 36 - Score: 0.1986
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2070(0.1875)
# Epoch: [37][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0995(0.0995) Grad: 1.7113  LR: 0.000133
# Epoch: [37][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1079(0.1096) Grad: 2.8074  LR: 0.000133
# Epoch: [37][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0954(0.1072) Grad: 3.2437  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1270(0.1270)
# Epoch 37 - avg_train_loss: 0.1072  avg_val_loss: 0.1928  time: 7s
# Epoch 37 - Score: 0.2024
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1849(0.1928)
# Epoch: [38][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1047(0.1047) Grad: 1.3486  LR: 0.000057
# Epoch: [38][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0654(0.0896) Grad: 1.8928  LR: 0.000057
# Epoch: [38][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0729(0.0906) Grad: 0.7756  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1204(0.1204)
# Epoch 38 - avg_train_loss: 0.0906  avg_val_loss: 0.1801  time: 7s
# Epoch 38 - Score: 0.1879
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1845(0.1801)
# Epoch: [39][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0708(0.0708) Grad: 2.1624  LR: 0.000009
# Epoch: [39][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0627(0.0764) Grad: 2.1379  LR: 0.000009
# Epoch: [39][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0691(0.0702) Grad: 0.8038  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1084(0.1084)
# Epoch 39 - avg_train_loss: 0.0702  avg_val_loss: 0.1737  time: 7s
# Epoch 39 - Score: 0.1838
# Epoch 39 - Save Best Score: 0.1838 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1709(0.1737)
# Epoch: [40][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0576(0.0576) Grad: 0.8306  LR: 0.000001
# Epoch: [40][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0630(0.0604) Grad: 0.8968  LR: 0.000001
# Epoch: [40][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0539(0.0627) Grad: 0.8122  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1055(0.1055)
# Epoch 40 - avg_train_loss: 0.0627  avg_val_loss: 0.1737  time: 7s
# Epoch 40 - Score: 0.1845
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1742(0.1737)
# ========== fold: 1 result ==========
# Score: 0.1838
# ========== fold: 2 training ==========
# Epoch: [1][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 3.2924(3.2924) Grad: 3.4943  LR: 0.000100
# Epoch: [1][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.7464(1.5506) Grad: 2.6661  LR: 0.000100
# Epoch: [1][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.5452(1.1608) Grad: 0.6316  LR: 0.000100
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.6833(0.6833)
# Epoch 1 - avg_train_loss: 1.1608  avg_val_loss: 0.7041  time: 7s
# Epoch 1 - Score: 0.7048
# Epoch 1 - Save Best Score: 0.7048 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.7765(0.7041)
# Epoch: [2][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.5597(0.5597) Grad: 1.0204  LR: 0.000057
# Epoch: [2][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4979(0.5826) Grad: 3.5809  LR: 0.000057
# Epoch: [2][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.5095(0.5786) Grad: 2.7951  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.6212(0.6212)
# Epoch 2 - avg_train_loss: 0.5786  avg_val_loss: 0.5785  time: 7s
# Epoch 2 - Score: 0.5796
# Epoch 2 - Save Best Score: 0.5796 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5434(0.5785)
# Epoch: [3][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.5616(0.5616) Grad: 2.9055  LR: 0.000009
# Epoch: [3][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3857(0.4951) Grad: 1.9734  LR: 0.000009
# Epoch: [3][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.4673(0.4681) Grad: 0.7848  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5523(0.5523)
# Epoch 3 - avg_train_loss: 0.4681  avg_val_loss: 0.5230  time: 7s
# Epoch 3 - Score: 0.5238
# Epoch 3 - Save Best Score: 0.5238 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4710(0.5230)
# Epoch: [4][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4644(0.4644) Grad: 1.3751  LR: 0.000001
# Epoch: [4][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4903(0.4153) Grad: 0.7061  LR: 0.000001
# Epoch: [4][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3365(0.4125) Grad: 1.7937  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.5438(0.5438)
# Epoch 4 - avg_train_loss: 0.4125  avg_val_loss: 0.5070  time: 7s
# Epoch 4 - Score: 0.5084
# Epoch 4 - Save Best Score: 0.5084 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4390(0.5070)
# Epoch: [5][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.4095(0.4095) Grad: 2.7989  LR: 0.000050
# Epoch: [5][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4509(0.4099) Grad: 1.5034  LR: 0.000050
# Epoch: [5][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3048(0.3999) Grad: 1.2706  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4992(0.4992)
# Epoch 5 - avg_train_loss: 0.3999  avg_val_loss: 0.4364  time: 7s
# Epoch 5 - Score: 0.4407
# Epoch 5 - Save Best Score: 0.4407 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3267(0.4364)
# Epoch: [6][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.3569(0.3569) Grad: 1.8702  LR: 0.000224
# Epoch: [6][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.4392(0.4742) Grad: 1.7392  LR: 0.000224
# Epoch: [6][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3743(0.4375) Grad: 1.0027  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4640(0.4640)
# Epoch 6 - avg_train_loss: 0.4375  avg_val_loss: 0.4313  time: 7s
# Epoch 6 - Score: 0.4334
# Epoch 6 - Save Best Score: 0.4334 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3427(0.4313)
# Epoch: [7][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4371(0.4371) Grad: 2.1363  LR: 0.000133
# Epoch: [7][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3163(0.3561) Grad: 1.3645  LR: 0.000133
# Epoch: [7][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3228(0.3364) Grad: 0.7745  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4182(0.4182)
# Epoch 7 - avg_train_loss: 0.3364  avg_val_loss: 0.3945  time: 7s
# Epoch 7 - Score: 0.3959
# Epoch 7 - Save Best Score: 0.3959 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3243(0.3945)
# Epoch: [8][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.2698(0.2698) Grad: 1.3732  LR: 0.000057
# Epoch: [8][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2677(0.2914) Grad: 2.2859  LR: 0.000057
# Epoch: [8][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1764(0.2829) Grad: 1.2814  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.4387(0.4387)
# Epoch 8 - avg_train_loss: 0.2829  avg_val_loss: 0.3923  time: 7s
# Epoch 8 - Score: 0.3944
# Epoch 8 - Save Best Score: 0.3944 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3399(0.3923)
# Epoch: [9][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.4067(0.4067) Grad: 1.4748  LR: 0.000009
# Epoch: [9][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.3385(0.2827) Grad: 1.6491  LR: 0.000009
# Epoch: [9][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2473(0.2645) Grad: 2.7228  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3663(0.3663)
# Epoch 9 - avg_train_loss: 0.2645  avg_val_loss: 0.3436  time: 7s
# Epoch 9 - Score: 0.3459
# Epoch 9 - Save Best Score: 0.3459 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2570(0.3436)
# Epoch: [10][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.1589(0.1589) Grad: 2.0602  LR: 0.000001
# Epoch: [10][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2810(0.2225) Grad: 1.9551  LR: 0.000001
# Epoch: [10][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1604(0.2292) Grad: 0.6594  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.3647(0.3647)
# Epoch 10 - avg_train_loss: 0.2292  avg_val_loss: 0.3413  time: 7s
# Epoch 10 - Score: 0.3432
# Epoch 10 - Save Best Score: 0.3432 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2636(0.3413)
# ...
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2622(0.2622)
# Epoch 10 - avg_train_loss: 0.2257  avg_val_loss: 0.2866  time: 7s
# Epoch 10 - Score: 0.2920
# Epoch 10 - Save Best Score: 0.2920 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1974(0.2866)
# Epoch: [11][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2150(0.2150) Grad: 0.6808  LR: 0.000050
# Epoch: [11][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2778(0.2062) Grad: 1.2814  LR: 0.000050
# Epoch: [11][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2681(0.2164) Grad: 2.3458  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2427(0.2427)
# Epoch 11 - avg_train_loss: 0.2164  avg_val_loss: 0.2852  time: 7s
# Epoch 11 - Score: 0.2897
# Epoch 11 - Save Best Score: 0.2897 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2408(0.2852)
# Epoch: [12][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2674(0.2674) Grad: 0.9849  LR: 0.000224
# Epoch: [12][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2618(0.2202) Grad: 1.9678  LR: 0.000224
# Epoch: [12][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2538(0.2140) Grad: 1.3090  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2236(0.2236)
# Epoch 12 - avg_train_loss: 0.2140  avg_val_loss: 0.2805  time: 7s
# Epoch 12 - Score: 0.2873
# Epoch 12 - Save Best Score: 0.2873 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2401(0.2805)
# Epoch: [13][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1821(0.1821) Grad: 0.9925  LR: 0.000133
# Epoch: [13][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.2404(0.1827) Grad: 2.3284  LR: 0.000133
# Epoch: [13][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.3053(0.1893) Grad: 1.9886  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2421(0.2421)
# Epoch 13 - avg_train_loss: 0.1893  avg_val_loss: 0.3040  time: 7s
# Epoch 13 - Score: 0.3103
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2787(0.3040)
# Epoch: [14][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.2201(0.2201) Grad: 0.8779  LR: 0.000057
# Epoch: [14][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1322(0.1925) Grad: 1.7995  LR: 0.000057
# Epoch: [14][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1623(0.1867) Grad: 1.0972  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2309(0.2309)
# Epoch 14 - avg_train_loss: 0.1867  avg_val_loss: 0.2854  time: 7s
# Epoch 14 - Score: 0.2910
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2560(0.2854)
# Epoch: [15][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1734(0.1734) Grad: 2.1306  LR: 0.000009
# Epoch: [15][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1839(0.1547) Grad: 1.2550  LR: 0.000009
# Epoch: [15][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1713(0.1538) Grad: 1.9728  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2221(0.2221)
# Epoch 15 - avg_train_loss: 0.1538  avg_val_loss: 0.2662  time: 7s
# Epoch 15 - Score: 0.2711
# Epoch 15 - Save Best Score: 0.2711 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2242(0.2662)
# Epoch: [16][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1835(0.1835) Grad: 2.3336  LR: 0.000001
# Epoch: [16][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1696(0.1507) Grad: 2.7286  LR: 0.000001
# Epoch: [16][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0851(0.1321) Grad: 0.8405  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2177(0.2177)
# Epoch 16 - avg_train_loss: 0.1321  avg_val_loss: 0.2651  time: 7s
# Epoch 16 - Score: 0.2718
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2077(0.2651)
# Epoch: [17][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1214(0.1214) Grad: 0.5866  LR: 0.000050
# Epoch: [17][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1560(0.1430) Grad: 2.8366  LR: 0.000050
# Epoch: [17][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1524(0.1358) Grad: 1.2964  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2076(0.2076)
# Epoch 17 - avg_train_loss: 0.1358  avg_val_loss: 0.2466  time: 7s
# Epoch 17 - Score: 0.2548
# Epoch 17 - Save Best Score: 0.2548 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1616(0.2466)
# Epoch: [18][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1558(0.1558) Grad: 1.9276  LR: 0.000224
# Epoch: [18][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1073(0.1342) Grad: 2.8441  LR: 0.000224
# Epoch: [18][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.2029(0.1413) Grad: 3.5174  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2310(0.2310)
# Epoch 18 - avg_train_loss: 0.1413  avg_val_loss: 0.2596  time: 7s
# Epoch 18 - Score: 0.2699
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1370(0.2596)
# Epoch: [19][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0720(0.0720) Grad: 3.3339  LR: 0.000133
# Epoch: [19][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1463(0.1607) Grad: 2.3071  LR: 0.000133
# Epoch: [19][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1558(0.1590) Grad: 2.5007  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2106(0.2106)
# Epoch 19 - avg_train_loss: 0.1590  avg_val_loss: 0.2587  time: 7s
# Epoch 19 - Score: 0.2681
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1744(0.2587)
# Epoch: [20][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1135(0.1135) Grad: 1.1808  LR: 0.000057
# Epoch: [20][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1025(0.1262) Grad: 1.1164  LR: 0.000057
# Epoch: [20][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0916(0.1271) Grad: 2.7393  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1927(0.1927)
# Epoch 20 - avg_train_loss: 0.1271  avg_val_loss: 0.2376  time: 7s
# Epoch 20 - Score: 0.2484
# Epoch 20 - Save Best Score: 0.2484 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1423(0.2376)
# Epoch: [21][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1107(0.1107) Grad: 2.0693  LR: 0.000009
# Epoch: [21][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1102(0.1037) Grad: 2.6028  LR: 0.000009
# Epoch: [21][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1301(0.1019) Grad: 1.4607  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1901(0.1901)
# Epoch 21 - avg_train_loss: 0.1019  avg_val_loss: 0.2301  time: 7s
# Epoch 21 - Score: 0.2410
# Epoch 21 - Save Best Score: 0.2410 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1288(0.2301)
# Epoch: [22][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0810(0.0810) Grad: 1.4042  LR: 0.000001
# Epoch: [22][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0665(0.0952) Grad: 2.2692  LR: 0.000001
# Epoch: [22][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1090(0.0941) Grad: 0.6260  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1887(0.1887)
# Epoch 22 - avg_train_loss: 0.0941  avg_val_loss: 0.2288  time: 7s
# Epoch 22 - Score: 0.2403
# Epoch 22 - Save Best Score: 0.2403 Model
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1233(0.2288)
# Epoch: [23][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0868(0.0868) Grad: 0.5458  LR: 0.000050
# Epoch: [23][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1168(0.0934) Grad: 0.6681  LR: 0.000050
# Epoch: [23][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0875(0.0957) Grad: 1.1982  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1971(0.1971)
# Epoch 23 - avg_train_loss: 0.0957  avg_val_loss: 0.2298  time: 7s
# Epoch 23 - Score: 0.2405
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1191(0.2298)
# Epoch: [24][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0566(0.0566) Grad: 0.5400  LR: 0.000224
# Epoch: [24][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0861(0.0916) Grad: 1.2457  LR: 0.000224
# Epoch: [24][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0921(0.0950) Grad: 2.5985  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2270(0.2270)
# Epoch 24 - avg_train_loss: 0.0950  avg_val_loss: 0.2668  time: 7s
# Epoch 24 - Score: 0.2732
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1969(0.2668)
# Epoch: [25][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1273(0.1273) Grad: 2.8996  LR: 0.000133
# Epoch: [25][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1101(0.1145) Grad: 3.4688  LR: 0.000133
# Epoch: [25][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1104(0.1180) Grad: 0.9428  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1923(0.1923)
# Epoch 25 - avg_train_loss: 0.1180  avg_val_loss: 0.2454  time: 7s
# Epoch 25 - Score: 0.2591
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1395(0.2454)
# Epoch: [26][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0918(0.0918) Grad: 3.3243  LR: 0.000057
# Epoch: [26][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0838(0.1056) Grad: 2.1920  LR: 0.000057
# Epoch: [26][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0977(0.1104) Grad: 0.6812  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2024(0.2024)
# Epoch 26 - avg_train_loss: 0.1104  avg_val_loss: 0.2409  time: 7s
# Epoch 26 - Score: 0.2522
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1298(0.2409)
# Epoch: [27][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0667(0.0667) Grad: 0.7904  LR: 0.000009
# Epoch: [27][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0562(0.0820) Grad: 1.9644  LR: 0.000009
# Epoch: [27][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0633(0.0819) Grad: 0.7663  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1907(0.1907)
# Epoch 27 - avg_train_loss: 0.0819  avg_val_loss: 0.2357  time: 7s
# Epoch 27 - Score: 0.2477
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1319(0.2357)
# Epoch: [28][0/19] Elapsed 0m 0s (remain 0m 6s) Loss: 0.0770(0.0770) Grad: 1.0289  LR: 0.000001
# Epoch: [28][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0729(0.0723) Grad: 2.0601  LR: 0.000001
# Epoch: [28][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0713(0.0739) Grad: 1.0551  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1888(0.1888)
# Epoch 28 - avg_train_loss: 0.0739  avg_val_loss: 0.2355  time: 7s
# Epoch 28 - Score: 0.2481
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1298(0.2355)
# Epoch: [29][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0959(0.0959) Grad: 1.1208  LR: 0.000050
# Epoch: [29][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0830(0.0857) Grad: 2.7687  LR: 0.000050
# Epoch: [29][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0586(0.0752) Grad: 1.1178  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1973(0.1973)
# Epoch 29 - avg_train_loss: 0.0752  avg_val_loss: 0.2394  time: 7s
# Epoch 29 - Score: 0.2509
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1336(0.2394)
# Epoch: [30][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0577(0.0577) Grad: 1.4608  LR: 0.000224
# Epoch: [30][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.1012(0.0782) Grad: 1.9125  LR: 0.000224
# Epoch: [30][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0983(0.0817) Grad: 3.8092  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1877(0.1877)
# Epoch 30 - avg_train_loss: 0.0817  avg_val_loss: 0.2411  time: 7s
# Epoch 30 - Score: 0.2530
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1520(0.2411)
# Epoch: [31][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0806(0.0806) Grad: 2.6120  LR: 0.000133
# Epoch: [31][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0834(0.0922) Grad: 0.9876  LR: 0.000133
# Epoch: [31][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1189(0.0927) Grad: 0.8785  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2328(0.2328)
# Epoch 31 - avg_train_loss: 0.0927  avg_val_loss: 0.2572  time: 7s
# Epoch 31 - Score: 0.2638
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1617(0.2572)
# Epoch: [32][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.1163(0.1163) Grad: 3.1574  LR: 0.000057
# Epoch: [32][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0696(0.0958) Grad: 1.7078  LR: 0.000057
# Epoch: [32][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0510(0.0901) Grad: 0.5896  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1794(0.1794)
# Epoch 32 - avg_train_loss: 0.0901  avg_val_loss: 0.2378  time: 7s
# Epoch 32 - Score: 0.2558
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1146(0.2378)
# Epoch: [33][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0630(0.0630) Grad: 0.6031  LR: 0.000009
# Epoch: [33][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0665(0.0647) Grad: 2.2835  LR: 0.000009
# Epoch: [33][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0915(0.0716) Grad: 1.6786  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1821(0.1821)
# Epoch 33 - avg_train_loss: 0.0716  avg_val_loss: 0.2372  time: 7s
# Epoch 33 - Score: 0.2527
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1253(0.2372)
# Epoch: [34][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0783(0.0783) Grad: 1.3985  LR: 0.000001
# Epoch: [34][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0702(0.0638) Grad: 2.6605  LR: 0.000001
# Epoch: [34][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0708(0.0646) Grad: 2.4891  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1798(0.1798)
# Epoch 34 - avg_train_loss: 0.0646  avg_val_loss: 0.2374  time: 7s
# Epoch 34 - Score: 0.2535
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1253(0.2374)
# Epoch: [35][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0326(0.0326) Grad: 0.6604  LR: 0.000050
# Epoch: [35][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0494(0.0598) Grad: 1.8917  LR: 0.000050
# Epoch: [35][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0488(0.0639) Grad: 1.0378  LR: 0.000050
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1841(0.1841)
# Epoch 35 - avg_train_loss: 0.0639  avg_val_loss: 0.2364  time: 7s
# Epoch 35 - Score: 0.2510
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1266(0.2364)
# Epoch: [36][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0414(0.0414) Grad: 1.6045  LR: 0.000224
# Epoch: [36][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0714(0.0708) Grad: 4.1165  LR: 0.000224
# Epoch: [36][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0843(0.0749) Grad: 2.1251  LR: 0.000224
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2008(0.2008)
# Epoch 36 - avg_train_loss: 0.0749  avg_val_loss: 0.2438  time: 7s
# Epoch 36 - Score: 0.2560
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1326(0.2438)
# Epoch: [37][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0459(0.0459) Grad: 1.2674  LR: 0.000133
# Epoch: [37][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0877(0.0818) Grad: 2.1935  LR: 0.000133
# Epoch: [37][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0891(0.0854) Grad: 3.7448  LR: 0.000133
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1888(0.1888)
# Epoch 37 - avg_train_loss: 0.0854  avg_val_loss: 0.2424  time: 7s
# Epoch 37 - Score: 0.2553
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1446(0.2424)
# Epoch: [38][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0765(0.0765) Grad: 1.4763  LR: 0.000057
# Epoch: [38][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0634(0.0828) Grad: 0.5664  LR: 0.000057
# Epoch: [38][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1214(0.0812) Grad: 0.6843  LR: 0.000057
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.2118(0.2118)
# Epoch 38 - avg_train_loss: 0.0812  avg_val_loss: 0.2339  time: 7s
# Epoch 38 - Score: 0.2442
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1110(0.2339)
# Epoch: [39][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0631(0.0631) Grad: 3.7752  LR: 0.000009
# Epoch: [39][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0595(0.0730) Grad: 2.7643  LR: 0.000009
# Epoch: [39][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.0527(0.0675) Grad: 2.1244  LR: 0.000009
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1971(0.1971)
# Epoch 39 - avg_train_loss: 0.0675  avg_val_loss: 0.2412  time: 7s
# Epoch 39 - Score: 0.2561
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1133(0.2412)
# Epoch: [40][0/19] Elapsed 0m 0s (remain 0m 5s) Loss: 0.0583(0.0583) Grad: 0.7990  LR: 0.000001
# Epoch: [40][10/19] Elapsed 0m 3s (remain 0m 2s) Loss: 0.0548(0.0478) Grad: 0.9251  LR: 0.000001
# Epoch: [40][18/19] Elapsed 0m 6s (remain 0m 0s) Loss: 0.1055(0.0533) Grad: 1.0501  LR: 0.000001
# EVAL: [0/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1974(0.1974)
# Epoch 40 - avg_train_loss: 0.0533  avg_val_loss: 0.2402  time: 7s
# Epoch 40 - Score: 0.2550
# EVAL: [2/3] Elapsed 0m 0s (remain 0m 0s) Loss: 0.1119(0.2402)
# ========== fold: 4 result ==========
# Score: 0.2403
# ========== CV ==========
# Score: 0.2156
