# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle as pkl

f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational = pkl.load(f)
f.close()
oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')
oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')
oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df_netweight.csv')

TK, PK = oof['KIc'], oof['preds']
TKfv, PKfv = oof2['KIc'], oof2['preds']
TKv, PKv = oof3['KIc'], oof3['preds']

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23

plt.subplot(1,4,1)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(plot_Y_rational[0][3], plot_Y_rational[1][3],".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("VGG16 + GP\n no fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(str(np.sqrt(np.mean((plot_Y_rational[0][3] - plot_Y_rational[1][3])**2)))[:5]), size=24, color="black")

plt.subplot(1,4,2)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TK, PK,".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("VGG16\n fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(np.sqrt(np.mean((TK - PK)**2)))[:5], size=24, color="black")

plt.subplot(1,4,3)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TKv, PKv,".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("ViT\n no fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(np.sqrt(np.mean((TKv - PKv)**2)))[:5], size=24, color="black")

plt.subplot(1,4,4)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TKfv, PKfv,".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("ViT\n fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(np.sqrt(np.mean((TKfv - PKfv)**2)))[:5], size=24, color="black")

plt.savefig('./Figure/GGplot4.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle as pkl

f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational = pkl.load(f)
f.close()
oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')
oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')

TK, PK = oof['KIc'], oof['preds']
TKv, PKv = oof2['KIc'], oof2['preds']

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23

plt.subplot(1,3,1)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(plot_Y_rational[0][3], plot_Y_rational[1][3],".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("VGG16 + GP\n no fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(str(np.sqrt(np.mean((plot_Y_rational[0][3] - plot_Y_rational[1][3])**2)))[:5]), size=24, color="black")

plt.subplot(1,3,2)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TK, PK,".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("VGG16\n fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(np.sqrt(np.mean((TK - PK)**2)))[:5], size=24, color="black")

plt.subplot(1,3,3)
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(TKv, PKv,".",c="black",label="test-folds")
plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("ViT\n fine-tuning")
plt.legend(loc="lower right",fontsize=20)
plt.xlim(1,5)
plt.ylim(1,5)
plt.text(1.05, 4.7, "RMSE(test)="+str(np.sqrt(np.mean((TKv - PKv)**2)))[:5], size=24, color="black")

plt.savefig('./Figure/GGplot.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# data
oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')
oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')\
    .sort_values(by='Id').reset_index(drop=True)
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational = pkl.load(f)
f.close()
oof['VGG+GP_preds'] = plot_Y_rational[1][3]
oof = oof.sort_values(by='Id').reset_index(drop=True)

# diff definition
oof['vgg_diff'] = abs(oof['preds'] - oof['KIc'])
oof2['vit_diff'] = abs(oof2['preds'] - oof2['KIc'])
vgg_gp = abs(oof['VGG+GP_preds'] - oof['KIc'])

# plot
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 16
plt.subplot(1,3,1)
plt.plot(oof2['KIc'], (oof['vgg_diff'] - oof2['vit_diff']),".", c="black")
plt.plot([-1,5],[0,0],"-",c="black")
plt.xlabel("True KIc")
plt.ylabel("VGG(|pred-label|)-ViT(|pred-label|)")
plt.title("ViT vs VGG16")
plt.xlim(1, 5)
plt.ylim(-2, 2)
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([-2, -1, 0, 1, 2])

plt.subplot(1,3,2)
plt.plot(oof2['KIc'], vgg_gp - oof['vgg_diff'],".", c="black")
plt.plot([-1,5],[0,0],"-",c="black")
plt.xlabel("True KIc")
plt.ylabel("VGG+GP(|pred-label|)-VGG(|pred-label|)")
plt.title("VGG16 vs VGG16+GP")
plt.xlim(1, 5)
plt.ylim(-2, 2)
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([-2, -1, 0, 1, 2])

plt.subplot(1,3,3)
plt.plot(oof2['KIc'], vgg_gp - oof2['vit_diff'],".", c="black")
plt.plot([-1,5],[0,0],"-",c="black")
plt.xlabel("True KIc")
plt.ylabel("VGG+GP(|pred-label|)-ViT(|pred-label|)")
plt.title("ViT vs VGG16+GP")
plt.xlim(1, 5)
plt.ylim(-2, 2)
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([-2, -1, 0, 1, 2])

plt.savefig('./Figure/diff.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import pandas as pd
import pickle as pkl

## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof2 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed10_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof3 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed20_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof4 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed51_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof5 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed111_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed10_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed20_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof4 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed51_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof5 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed111_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)

## vgg+GP
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational42 = pkl.load(f)
f.close()
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed10.pkl","rb")
plot_Y_rational10 = pkl.load(f)
f.close()
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed20.pkl","rb")
plot_Y_rational20 = pkl.load(f)
f.close()
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed51.pkl","rb")
plot_Y_rational51 = pkl.load(f)
f.close()
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed111.pkl","rb")
plot_Y_rational111 = pkl.load(f)
f.close()

## vgg 
true_kic = vgg_oof['KIc']  
predicted_kic = vgg_oof['preds']  

true_kic2 = vgg_oof2['KIc']  
predicted_kic2 = vgg_oof2['preds']  

true_kic3 = vgg_oof3['KIc']  
predicted_kic3 = vgg_oof3['preds']  

true_kic4 = vgg_oof4['KIc']  
predicted_kic4 = vgg_oof4['preds']  

true_kic5 = vgg_oof5['KIc']  
predicted_kic5 = vgg_oof5['preds']  

## vit
true_kic_vit = vit_oof['KIc']  
predicted_kic_vit = vit_oof['preds']  

true_kic_vit2 = vit_oof2['KIc']  
predicted_kic_vit2 = vit_oof2['preds']  

true_kic_vit3 = vit_oof3['KIc']  
predicted_kic_vit3 = vit_oof3['preds']  

true_kic_vit4 = vit_oof4['KIc']  
predicted_kic_vit4 = vit_oof4['preds']  

true_kic_vit5 = vit_oof5['KIc']  
predicted_kic_vit5 = vit_oof5['preds']  

## VGG + GP
true_kic_vgg_gau = pd.Series(plot_Y_rational42[0][3])  
predicted_kic_vgg_gau = pd.Series(plot_Y_rational42[1][3])  

true_kic_vgg_gau2 = pd.Series(plot_Y_rational10[0][3])  
predicted_kic_vgg_gau2 = pd.Series(plot_Y_rational10[1][3])  

true_kic_vgg_gau3 = pd.Series(plot_Y_rational20[0][3])  
predicted_kic_vgg_gau3 = pd.Series(plot_Y_rational20[1][3])  

true_kic_vgg_gau4 = pd.Series(plot_Y_rational51[0][3])  
predicted_kic_vgg_gau4 = pd.Series(plot_Y_rational51[1][3])  

true_kic_vgg_gau5 = pd.Series(plot_Y_rational111[0][3])  
predicted_kic_vgg_gau5 = pd.Series(plot_Y_rational111[1][3]) 
    
     
# 区切りの数
num_bins = 9

# 区切りの幅を計算
bin_width = (np.max(true_kic) - np.min(true_kic)) / num_bins

# 区切りごとにPredicted KICの平均値を計算
bin_centers = []
predicted_kic_means = []
predicted_kic_means_vit = []
predicted_kic_means_vgg_gau = []
predicted_kic_std = []
predicted_kic_std_vit = []
predicted_kic_std_vgg_gau = []

for i in range(num_bins):
    bin_lower = np.min(true_kic) + i * bin_width
    bin_upper = bin_lower + bin_width
    
    # 区間内のvggの予測値
    bin_mask = (true_kic >= bin_lower) & (true_kic < bin_upper)
    bin_true_kic = pd.concat([true_kic[bin_mask],true_kic2[bin_mask],
                              true_kic3[bin_mask],true_kic4[bin_mask],
                              true_kic5[bin_mask]], ignore_index=True, axis=0)
    bin_predicted_kic = pd.concat([predicted_kic[bin_mask],predicted_kic2[bin_mask],
                                   predicted_kic3[bin_mask],predicted_kic4[bin_mask],
                                   predicted_kic5[bin_mask]], ignore_index=True, axis=0)
    bin_centers.append((bin_lower + bin_upper) / 2)
    predicted_kic_means.append(np.mean(bin_predicted_kic))
    predicted_kic_std.append(bin_predicted_kic.std(ddof=0) / np.sqrt(len(bin_predicted_kic)))
    
    # 区間内のvitの予測値
    bin_mask_vit = (true_kic_vit >= bin_lower) & (true_kic_vit < bin_upper)
    bin_true_kic_vit = pd.concat([true_kic_vit[bin_mask_vit],true_kic_vit2[bin_mask_vit],
                                  true_kic_vit3[bin_mask_vit],true_kic_vit4[bin_mask_vit],
                                  true_kic_vit5[bin_mask_vit]], ignore_index=True, axis=0)
    bin_predicted_kic_vit = pd.concat([predicted_kic_vit[bin_mask_vit],
                                       predicted_kic_vit2[bin_mask_vit],
                                       predicted_kic_vit3[bin_mask_vit],
                                       predicted_kic_vit4[bin_mask_vit],
                                       predicted_kic_vit5[bin_mask_vit]], 
                                       ignore_index=True, axis=0)
    predicted_kic_means_vit.append(np.mean(bin_predicted_kic_vit))
    predicted_kic_std_vit.append(bin_predicted_kic_vit.std(ddof=0) / \
                                  np.sqrt(len(bin_predicted_kic_vit)))
    
    # 区間内のvgg+GPの予測値
    bin_mask_vgg_gau = (true_kic_vgg_gau >= bin_lower) & (true_kic_vgg_gau < bin_upper)
    bin_mask_vgg_gau2 = (true_kic_vgg_gau2 >= bin_lower) & (true_kic_vgg_gau2 < bin_upper)
    bin_mask_vgg_gau3 = (true_kic_vgg_gau3 >= bin_lower) & (true_kic_vgg_gau3 < bin_upper)
    bin_mask_vgg_gau4 = (true_kic_vgg_gau4 >= bin_lower) & (true_kic_vgg_gau4 < bin_upper)
    bin_mask_vgg_gau5 = (true_kic_vgg_gau5 >= bin_lower) & (true_kic_vgg_gau5 < bin_upper)
    bin_true_kic_vgg_gau = np.concatenate([true_kic_vgg_gau[bin_mask_vgg_gau],
                                           true_kic_vgg_gau2[bin_mask_vgg_gau2],
                                           true_kic_vgg_gau3[bin_mask_vgg_gau3],
                                           true_kic_vgg_gau4[bin_mask_vgg_gau4],
                                           true_kic_vgg_gau5[bin_mask_vgg_gau5]], axis=0)
    bin_predicted_kic_vgg_gau = np.concatenate([predicted_kic_vgg_gau[bin_mask_vgg_gau],
                                                predicted_kic_vgg_gau2[bin_mask_vgg_gau2],
                                                predicted_kic_vgg_gau3[bin_mask_vgg_gau3],
                                                predicted_kic_vgg_gau4[bin_mask_vgg_gau4],
                                                predicted_kic_vgg_gau5[bin_mask_vgg_gau5]],
                                                 axis=0)
    predicted_kic_means_vgg_gau.append(np.mean(bin_predicted_kic_vgg_gau))
    predicted_kic_std_vgg_gau.append(bin_predicted_kic_vgg_gau.std(ddof=0) / \
                                     np.sqrt(len(bin_predicted_kic_vgg_gau)))

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23

plt.figure(figsize=(5, 5))
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(bin_centers, predicted_kic_means_vgg_gau, 'b-', label='VGG16 + GP (no fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means_vgg_gau+np.array(predicted_kic_std_vgg_gau), 
                 predicted_kic_means_vgg_gau-np.array(predicted_kic_std_vgg_gau), 
                 alpha=0.15)
plt.plot(bin_centers, predicted_kic_means, 'r-', label='VGG16 (fine-tuning)')
plt.fill_between(bin_centers, predicted_kic_means+np.array(predicted_kic_std), 
                 predicted_kic_means-np.array(predicted_kic_std), alpha=0.15)
plt.plot(bin_centers, predicted_kic_means_vit, 'g-', label='ViT (fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means_vit+np.array(predicted_kic_std_vit),
                 predicted_kic_means_vit-np.array(predicted_kic_std_vit), 
                 alpha=0.15)

plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("各モデルの系統誤差")
plt.legend(loc="upper left",fontsize=10)
plt.xlim(1,5)
plt.ylim(1,5)
plt.savefig('./Figure/average_grit_plot_5seed.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import pandas as pd
import pickle as pkl

## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
true_kic = vgg_oof['KIc']  
predicted_kic = vgg_oof['preds'] 

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
true_kic_vit = vit_oof['KIc']  
predicted_kic_vit = vit_oof['preds']  

## vgg+GP
f = open("./Mototake_Analysis/VGG+GP/Y_pred_rational_seed42.pkl","rb")
plot_Y_rational42 = pkl.load(f)
f.close() 
true_kic_vgg_gau = pd.Series(plot_Y_rational42[0][3])  
predicted_kic_vgg_gau = pd.Series(plot_Y_rational42[1][3])  
      
# 区切りの数
num_bins = 9

# 区切りの幅を計算
bin_width = (np.max(true_kic) - np.min(true_kic)) / num_bins

# 区切りごとにPredicted KICの平均値を計算
bin_centers = []
predicted_kic_means = []
predicted_kic_means_vit = []
predicted_kic_means_vgg_gau = []
predicted_kic_std = []
predicted_kic_std_vit = []
predicted_kic_std_vgg_gau = []

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23
plt.figure(figsize=(5, 5))

for i in range(num_bins):
    bin_lower = np.min(true_kic) + i * bin_width
    bin_upper = bin_lower + bin_width
    plt.vlines(bin_lower, 1, 5, colors="gray")
    
    bin_mask = (true_kic >= bin_lower) & (true_kic < bin_upper)
    bin_true_kic = true_kic[bin_mask]
    bin_predicted_kic = predicted_kic[bin_mask]
    bin_centers.append((bin_lower + bin_upper) / 2)
    predicted_kic_means.append(np.mean(bin_predicted_kic))
    predicted_kic_std.append(bin_predicted_kic.std(ddof=0) / np.sqrt(len(bin_predicted_kic)))
    
    bin_mask_vit = (true_kic_vit >= bin_lower) & (true_kic_vit < bin_upper)
    bin_true_kic_vit = true_kic_vit[bin_mask_vit]
    bin_predicted_kic_vit = predicted_kic_vit[bin_mask_vit]
    predicted_kic_means_vit.append(np.mean(bin_predicted_kic_vit))
    predicted_kic_std_vit.append(bin_predicted_kic_vit.std(ddof=0) / \
                                 np.sqrt(len(bin_predicted_kic_vit)))
    
    bin_mask_vgg_gau = (true_kic_vgg_gau >= bin_lower) & (true_kic_vgg_gau < bin_upper)
    bin_true_kic_vgg_gau = true_kic_vgg_gau[bin_mask_vgg_gau]
    bin_predicted_kic_vgg_gau = predicted_kic_vgg_gau[bin_mask_vgg_gau]
    predicted_kic_means_vgg_gau.append(np.mean(bin_predicted_kic_vgg_gau))
    predicted_kic_std_vgg_gau.append(bin_predicted_kic_vgg_gau.std(ddof=0) / \
                                     np.sqrt(len(bin_predicted_kic_vgg_gau)))

plt.vlines(bin_upper, 1, 5, colors="gray")
plt.plot([np.min(true_kic), np.max(true_kic)], [np.min(true_kic), np.max(true_kic)], "-", c="gray")
plt.plot([1,5],[1,5],"-",c="gray")
plt.plot(bin_centers, predicted_kic_means_vgg_gau, 'b-', label='VGG16 + GP (no fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means_vgg_gau+np.array(predicted_kic_std_vgg_gau), 
                 predicted_kic_means_vgg_gau-np.array(predicted_kic_std_vgg_gau), 
                 alpha=0.15)
plt.plot(bin_centers, predicted_kic_means, 'r-', label='VGG16 (fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means+np.array(predicted_kic_std), 
                 predicted_kic_means-np.array(predicted_kic_std), alpha=0.15)
plt.plot(bin_centers, predicted_kic_means_vit, 'g-', label='ViT (fine-tuning)')
plt.fill_between(bin_centers, 
                 predicted_kic_means_vit+np.array(predicted_kic_std_vit), 
                 predicted_kic_means_vit-np.array(predicted_kic_std_vit), alpha=0.15)

plt.xlabel("True KIc")
plt.ylabel("Predicted KIc")
plt.title("Systematic error for each model", x=0.5, y=1.05)
plt.legend(loc="upper left",fontsize=10)
plt.xlim(1,5)
plt.ylim(1,5)
plt.savefig('./Figure/average_grit_plot_42seed.png', bbox_inches="tight", pad_inches=0.1)
plt.show()

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
 
np.random.seed(0)
 
def barplot_annotate_brackets(num1, num2, data, center, 
                              height, yerr=None, dh=.05, 
                              barh=.05, fs=None, maxasterix=None):
    """ 
    Annotate barplot with p-values.
  
    :param num1: number of left bar to put bracket over
    :param num2: number of right bar to put bracket over
    :param data: string to write or number for generating asterixes
    :param center: centers of all bars (like plt.bar() input)
    :param height: heights of all bars (like plt.bar() input)
    :param yerr: yerrs of all bars (like plt.bar() input)
    :param dh: height offset over bar / bar + yerr in axes coordinates (0 to 1)
    :param barh: bar height in axes coordinates (0 to 1)
    :param fs: font size
    :param maxasterix: maximum number of asterixes to write (for very small p-values)
    """
  
    if type(data) is str:
        text = data
    else:
        # * is p < 0.05
        # ** is p < 0.005
        # *** is p < 0.0005
        # ↓↓↓↓↓↓↓↓↓↓↓
        # * is p < 0.05
        # ** is p < 0.01
        # *** is p < 0.001
        # etc.
        text = ''
        p = .05
  
        while data < p:
            text += '*'
            p /= 10.
  
            if maxasterix and len(text) == maxasterix:
                break
        
        if data >= 0.1:
            text = 'n. s.'
        elif data < 0.1 and data >= 0.05:
            text = '†'
        elif data < 0.05 and data >= 0.01:
            text = '*'
        elif data < 0.01 and data >= 0.001:
            text = '**'
        elif data < 0.001:
            text = '***'
        
  
    lx, ly = center[num1], height[num1]
    rx, ry = center[num2], height[num2]
  
    if yerr:
        ly += yerr[num1]
        ry += yerr[num2]
  
    ax_y0, ax_y1 = plt.gca().get_ylim()
    dh *= (ax_y1 - ax_y0)
    barh *= (ax_y1 - ax_y0)
  
    y = max(ly, ry) + dh
  
    barx = [lx, lx, rx, rx]
    bary = [y, y+barh, y+barh, y]
    mid = ((lx+rx)/2, y+barh)
  
    plt.plot(barx, bary, c='black')
  
    kwargs = dict(ha='center', va='bottom')
    if fs is not None:
        kwargs['fontsize'] = fs
  
    plt.text(*mid, text, **kwargs)
    
    #ボックス作成
    pos = plt.gca().get_position()
    s_text = "n. s. : not significant\n† : p < 0.1\n* : p < 0.05\n** : p < 0.01 \
             \n*** : p < 0.001"
    dic_box = {
        'facecolor' : 'whitesmoke',
        'edgecolor' : 'black',
        'linewidth' : 1
    }

    #文字とボックスの挿入
    plt.text(5.5, 0.30, s=s_text, 
            color='black', ha='center', fontsize='13', 
            bbox=dic_box)
    
""" main """
## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof2 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed10_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof3 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed20_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof4 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed51_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof5 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed111_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed10_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed20_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof4 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed51_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof5 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed111_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)

vgg_rmse = []
vit_rmse = []

vgg_rmse.append(mean_squared_error(vgg_oof['KIc'], vgg_oof['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof['KIc'], vit_oof['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof2['KIc'], vgg_oof2['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof2['KIc'], vit_oof2['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof3['KIc'], vgg_oof3['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof3['KIc'], vit_oof3['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof4['KIc'], vgg_oof4['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof4['KIc'], vit_oof4['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof5['KIc'], vgg_oof5['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof5['KIc'], vit_oof5['preds'], squared=False))

# Generate toy data
x0 = vit_rmse
x1 = vgg_rmse
 
# Welch’s t-test
t01_value, p01_value = stats.ttest_rel(vgg_rmse, vit_rmse, alternative='greater') 
 
""" plot """
heights = [0, np.mean(x0), 0, np.mean(x1), 0]
std = [0, np.std(x0)/np.sqrt(5), 0, np.std(x1)/np.sqrt(5), 0]
label = ['', 'ViT', '', 'VGG', '']
width = 0.8 # the width of the bars
bars = np.arange(5)
  
# データの作成
data = pd.DataFrame({
    'Method': ['ViT'] * 5 + ['VGG'] * 5,
    'RMSE': vit_rmse + vgg_rmse
})

# 箱ひげ図と点を結ぶグラフの描画
plt.figure(figsize=(8, 5))
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23 
plt.xticks([0, 1, 2, 3, 4], label)

# 各点を結ぶ線の描画
for i in range(0, 5):
    method1 = data['RMSE'][i]
    method2 = data['RMSE'][i+5]
    plt.plot([1, 3], [method1, method2], color="black", marker='.', markersize=12, 
             linestyle="-", linewidth=2)   

# グラフの装飾
plt.xlabel("Method")
plt.ylabel("RMSE")
plt.ylim(0.27, 0.34)
plt.xlim(0, 4)
plt.title("VGG vs ViT")
barplot_annotate_brackets(1, 3, p01_value, bars, heights, yerr=std, dh=.15)

plt.tight_layout()
plt.savefig('./Figure/paired_ttest_*.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()

# plt.bar(bars, heights, width, tick_label=label, yerr=std,
#         align='center', alpha=0.5, ecolor='black', capsize=5)
# Out:
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
 
np.random.seed(0)
 
def barplot_annotate_brackets(num1, num2, data, center, 
                              height, yerr=None, dh=.05, 
                              barh=.05, fs=None, maxasterix=None):
    """ 
    Annotate barplot with p-values.
  
    :param num1: number of left bar to put bracket over
    :param num2: number of right bar to put bracket over
    :param data: string to write or number for generating asterixes
    :param center: centers of all bars (like plt.bar() input)
    :param height: heights of all bars (like plt.bar() input)
    :param yerr: yerrs of all bars (like plt.bar() input)
    :param dh: height offset over bar / bar + yerr in axes coordinates (0 to 1)
    :param barh: bar height in axes coordinates (0 to 1)
    :param fs: font size
    :param maxasterix: maximum number of asterixes to write (for very small p-values)
    """
  
    if type(data) is str:
        text = data
    else:
        # * is p < 0.05
        # ** is p < 0.005
        # *** is p < 0.0005
        # ↓↓↓↓↓↓↓↓↓↓↓
        # * is p < 0.05
        # ** is p < 0.01
        # *** is p < 0.001
        # etc.
        text = ''
        p = .05
  
        while data < p:
            text += '*'
            p /= 10.
  
            if maxasterix and len(text) == maxasterix:
                break
        
        if data >= 0.1:
            text = 'n. s.'
        elif data < 0.1 and data >= 0.05:
            text = '†'
        elif data < 0.05 and data >= 0.01:
            text = '*'
        elif data < 0.01 and data >= 0.001:
            text = '**'
        elif data < 0.001:
            text = '***'
        
  
    lx, ly = center[num1], height[num1]
    rx, ry = center[num2], height[num2]
  
    if yerr:
        ly += yerr[num1]
        ry += yerr[num2]
  
    ax_y0, ax_y1 = plt.gca().get_ylim()
    dh *= (ax_y1 - ax_y0)
    barh *= (ax_y1 - ax_y0)
  
    y = max(ly, ry) + dh
  
    barx = [lx, lx, rx, rx]
    bary = [y, y+barh, y+barh, y]
    mid = ((lx+rx)/2, y+barh)
  
    plt.plot(barx, bary, c='black')
  
    kwargs = dict(ha='center', va='bottom')
    if fs is not None:
        kwargs['fontsize'] = fs
  
    plt.text(*mid, text, **kwargs)
    
    #ボックス作成
    pos = plt.gca().get_position()
    s_text = "n. s. : not significant\n† : p < 0.1\n* : p < 0.05\n** : p < 0.01 \
             \n*** : p < 0.001"
    dic_box = {
        'facecolor' : 'whitesmoke',
        'edgecolor' : 'black',
        'linewidth' : 1
    }

    #文字とボックスの挿入
    plt.text(5.5, 0.20, s=s_text, 
            color='black', ha='center', fontsize='13', 
            bbox=dic_box)
    
""" main """
## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed42_bootstrap_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof2 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed10_bootstrap_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof3 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed20_bootstrap_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof4 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed51_bootstrap_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof5 = pd.read_csv('./KIc/Model/vgg/vgg16_Kfold_seed111_bootstrap_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed42_bootstrap_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed10_bootstrap_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed20_bootstrap_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof4 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed51_bootstrap_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof5 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_Kfold_seed111_bootstrap_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)

vgg_rmse = []
vit_rmse = []

vgg_rmse.append(mean_squared_error(vgg_oof['KIc'], vgg_oof['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof['KIc'], vit_oof['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof2['KIc'], vgg_oof2['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof2['KIc'], vit_oof2['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof3['KIc'], vgg_oof3['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof3['KIc'], vit_oof3['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof4['KIc'], vgg_oof4['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof4['KIc'], vit_oof4['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof5['KIc'], vgg_oof5['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof5['KIc'], vit_oof5['preds'], squared=False))

# Generate toy data
x0 = vit_rmse
x1 = vgg_rmse
 
# Welch’s t-test
t01_value, p01_value = stats.ttest_rel(vgg_rmse, vit_rmse, alternative='greater') 
 
""" plot """
heights = [0, np.mean(x0), 0, np.mean(x1), 0]
std = [0, np.std(x0)/np.sqrt(5), 0, np.std(x1)/np.sqrt(5), 0]
label = ['', 'ViT', '', 'VGG', '']
width = 0.8 # the width of the bars
bars = np.arange(5)
  
# データの作成
data = pd.DataFrame({
    'Method': ['ViT'] * 5 + ['VGG'] * 5,
    'RMSE': vit_rmse + vgg_rmse
})

# 箱ひげ図と点を結ぶグラフの描画
plt.figure(figsize=(8, 5))
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23 
plt.xticks([0, 1, 2, 3, 4], label)

# 各点を結ぶ線の描画
for i in range(0, 5):
    method1 = data['RMSE'][i]
    method2 = data['RMSE'][i+5]
    plt.plot([1, 3], [method1, method2], color="black", marker='.', markersize=12, 
             linestyle="-", linewidth=2)   

# グラフの装飾
plt.xlabel("Method")
plt.ylabel("RMSE")
plt.ylim(0.18, 0.25)
plt.xlim(0, 4)
plt.title("VGG vs ViT")
barplot_annotate_brackets(1, 3, p01_value, bars, heights, yerr=std, dh=.15)

plt.tight_layout()
plt.savefig('./Figure/paired_ttest_*.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()

# plt.bar(bars, heights, width, tick_label=label, yerr=std,
#         align='center', alpha=0.5, ecolor='black', capsize=5)
# Out:
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
 
np.random.seed(0)
 
def barplot_annotate_brackets(num1, num2, data, center, 
                              height, yerr=None, dh=.05, 
                              barh=.05, fs=None, maxasterix=None):
    """ 
    Annotate barplot with p-values.
  
    :param num1: number of left bar to put bracket over
    :param num2: number of right bar to put bracket over
    :param data: string to write or number for generating asterixes
    :param center: centers of all bars (like plt.bar() input)
    :param height: heights of all bars (like plt.bar() input)
    :param yerr: yerrs of all bars (like plt.bar() input)
    :param dh: height offset over bar / bar + yerr in axes coordinates (0 to 1)
    :param barh: bar height in axes coordinates (0 to 1)
    :param fs: font size
    :param maxasterix: maximum number of asterixes to write (for very small p-values)
    """
  
    if type(data) is str:
        text = data
    else:
        # * is p < 0.05
        # ** is p < 0.005
        # *** is p < 0.0005
        # ↓↓↓↓↓↓↓↓↓↓↓
        # * is p < 0.05
        # ** is p < 0.01
        # *** is p < 0.001
        # etc.
        text = ''
        p = .05
  
        while data < p:
            text += '*'
            p /= 10.
  
            if maxasterix and len(text) == maxasterix:
                break
        
        if data >= 0.1:
            text = 'n. s.'
        elif data < 0.1 and data >= 0.05:
            text = '†'
        elif data < 0.05 and data >= 0.01:
            text = '*'
        elif data < 0.01 and data >= 0.001:
            text = '**'
        elif data < 0.001:
            text = '***'
        
  
    lx, ly = center[num1], height[num1]
    rx, ry = center[num2], height[num2]
  
    if yerr:
        ly += yerr[num1]
        ry += yerr[num2]
  
    ax_y0, ax_y1 = plt.gca().get_ylim()
    dh *= (ax_y1 - ax_y0)
    barh *= (ax_y1 - ax_y0)
  
    y = max(ly, ry) + dh
  
    barx = [lx, lx, rx, rx]
    bary = [y, y+barh, y+barh, y]
    mid = ((lx+rx)/2, y+barh)
  
    plt.plot(barx, bary, c='black')
  
    kwargs = dict(ha='center', va='bottom')
    if fs is not None:
        kwargs['fontsize'] = fs
  
    plt.text(*mid, text, **kwargs)
    
    #ボックス作成
    pos = plt.gca().get_position()
    s_text = "n. s. : not significant \n† : p < 0.1 \n* : p < 0.05 \n      ** : p < 0.01\
             \n*** : p < 0.001"
    dic_box = {
        'facecolor' : 'whitesmoke',
        'edgecolor' : 'black',
        'linewidth' : 1
    }

    #文字とボックスの挿入
    plt.text(pos.x1+5, pos.y1-0.5, s=s_text, 
            color='black', ha='center', fontsize='13', 
            bbox=dic_box)
    
""" main """
## vgg
vgg_oof = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed42_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof2 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed10_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof3 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed20_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof4 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed51_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof5 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed111_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof6 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed19_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof7 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed23_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof8 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed34_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof9 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed40_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof10 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed56_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof11 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed77_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof12 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed88_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof13 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed99_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof14 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed12_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof15 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed45_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof16 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed67_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof17 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed78_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof18 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed89_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof19 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed18_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)
vgg_oof20 = pd.read_csv('./KIc/Model/vgg/vgg16_bootstrap_seed24_oof_df.csv') \
        .sort_values(by='Id').reset_index(drop=True)

## vit
vit_oof = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed42_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof2 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed10_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof3 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed20_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof4 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed51_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof5 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed111_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof6 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed19_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof7 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed23_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof8 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed34_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof9 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed40_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof10 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed56_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof11 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed77_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof12 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed88_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof13 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed99_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof14 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed12_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof15 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed45_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof16 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed67_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof17 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed78_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof18 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed89_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof19 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed18_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)
vit_oof20 = pd.read_csv('./KIc/Model/vit/vit_large_patch32_224_bootstrap_seed24_oof_df.csv')\
        .sort_values(by='Id').reset_index(drop=True)

vgg_rmse = []
vit_rmse = []

vgg_rmse.append(mean_squared_error(vgg_oof['KIc'], vgg_oof['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof['KIc'], vit_oof['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof2['KIc'], vgg_oof2['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof2['KIc'], vit_oof2['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof3['KIc'], vgg_oof3['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof3['KIc'], vit_oof3['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof4['KIc'], vgg_oof4['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof4['KIc'], vit_oof4['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof5['KIc'], vgg_oof5['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof5['KIc'], vit_oof5['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof6['KIc'], vgg_oof6['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof6['KIc'], vit_oof6['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof7['KIc'], vgg_oof7['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof7['KIc'], vit_oof7['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof8['KIc'], vgg_oof8['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof8['KIc'], vit_oof8['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof9['KIc'], vgg_oof9['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof9['KIc'], vit_oof9['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof10['KIc'], vgg_oof10['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof10['KIc'], vit_oof10['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof11['KIc'], vgg_oof11['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof11['KIc'], vit_oof11['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof12['KIc'], vgg_oof12['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof12['KIc'], vit_oof12['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof13['KIc'], vgg_oof13['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof13['KIc'], vit_oof13['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof14['KIc'], vgg_oof14['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof14['KIc'], vit_oof14['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof15['KIc'], vgg_oof15['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof15['KIc'], vit_oof15['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof16['KIc'], vgg_oof16['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof16['KIc'], vit_oof16['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof17['KIc'], vgg_oof17['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof17['KIc'], vit_oof17['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof18['KIc'], vgg_oof18['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof18['KIc'], vit_oof18['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof19['KIc'], vgg_oof19['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof19['KIc'], vit_oof19['preds'], squared=False))

vgg_rmse.append(mean_squared_error(vgg_oof20['KIc'], vgg_oof20['preds'], squared=False))
vit_rmse.append(mean_squared_error(vit_oof20['KIc'], vit_oof20['preds'], squared=False))

# Generate toy data
x0 = vit_rmse
x1 = vgg_rmse
 
# Welch’s t-test
t01_value, p01_value = stats.ttest_rel(vgg_rmse, vit_rmse, alternative='greater') 
 
""" plot """
n = len(vgg_rmse)
heights = [0, np.mean(x0), 0, np.mean(x1), 0]
std = [0, np.std(x0), 0, np.std(x1), 0]
label = ['', 'ViT', '', 'VGG', '']
width = 0.8 # the width of the bars
bars = np.arange(n)
  
# データの作成
data = pd.DataFrame({
    'Method': ['ViT'] * n + ['VGG'] * n,
    'RMSE': vit_rmse + vgg_rmse
})

# 箱ひげ図と点を結ぶグラフの描画
plt.figure(figsize=(10, 6))
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23 
plt.xticks([i for i in range(5)], label)

# 各点を結ぶ線の描画
for i in range(0, n):
    method1 = data['RMSE'][i]
    method2 = data['RMSE'][i+n]
    plt.plot([1, 3], [method1, method2], color="black", marker='.', markersize=12, 
             linestyle="-", linewidth=2)   

# グラフの装飾
plt.xlabel("Method")
plt.ylabel("RMSE")
plt.ylim(0.25, 0.42)
plt.xlim(0, 4)
plt.title("VGG vs ViT")
barplot_annotate_brackets(1, 3, p01_value, bars, heights, yerr=std, dh=.2)

plt.tight_layout()
plt.savefig('./Figure/paired_ttest_*.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()

# plt.bar(bars, heights, width, tick_label=label, yerr=std,
#         align='center', alpha=0.5, ecolor='black', capsize=5)
# Out:
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
vit_rmse
# Out:
# [0.33339367838658973,
#  0.3374347564089075,
#  0.28879736871037703,
#  0.33939435096456505,
#  0.3044101447261453]

# %%
vgg_rmse
# Out:
# [0.34189519111861516,
#  0.2999682645866269,
#  0.33475110311126116,
#  0.3761891817630621,
#  0.3281920488443285]

# %%
p01_value
# Out:
# 0.17495877173626742

# %%
import numpy as np
from scipy import stats

# Define your two sample data
sample1 = vit_rmse
sample2 = vgg_rmse

# Set the number of bootstrap iterations
n_iterations = 1000

# Initialize an array to store the test statistics
bootstrap_stats = np.zeros(n_iterations)

# Perform the bootstrap iterations
for i in range(n_iterations):
    # Create bootstrap samples by sampling with replacement
    bootstrap_sample1 = np.random.choice(sample1, size=len(sample1), replace=True)
    bootstrap_sample2 = np.random.choice(sample2, size=len(sample2), replace=True)
    
    # Calculate the test statistic for the bootstrap samples
    # bootstrap_stats[i] = test_statistic(bootstrap_sample1, bootstrap_sample2)
    bootstrap_stats[i], _ = stats.ttest_ind(bootstrap_sample2, bootstrap_sample1, equal_var=False)

# Calculate Welch's t-test statistic
observed_statistic, _ = stats.ttest_ind(sample2, sample1, equal_var=False)

# Calculate the p-value
p_value = (np.abs(bootstrap_stats) >= np.abs(observed_statistic)).mean()

# Print the p-value
print("p-value:", p_value)
# Out:
# /home/yamanaka/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# p-value: 0.651

# %%
observed_statistic
# Out:
# -4.76850676782301

# %%
bootstrap_stats
# Out:
# array([-5.49814713, -4.21331933, -3.41109277, -8.18327662, -3.97086211,
#        -4.71574525, -5.55783042, -3.27936806, -8.30485248, -4.05621919,
#        -2.89741746, -7.30359154, -4.55452134, -4.14643074, -5.55783042,
#        -4.80688294, -4.10068487, -5.97753698, -4.78605043, -4.97635315])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def barplot_annotate_brackets(num1, num2, data, center, 
                              height, yerr=None, dh=.05, 
                              barh=.05, fs=None, maxasterix=None):
    """ 
    Annotate barplot with p-values.
  
    :param num1: number of left bar to put bracket over
    :param num2: number of right bar to put bracket over
    :param data: string to write or number for generating asterixes
    :param center: centers of all bars (like plt.bar() input)
    :param height: heights of all bars (like plt.bar() input)
    :param yerr: yerrs of all bars (like plt.bar() input)
    :param dh: height offset over bar / bar + yerr in axes coordinates (0 to 1)
    :param barh: bar height in axes coordinates (0 to 1)
    :param fs: font size
    :param maxasterix: maximum number of asterixes to write (for very small p-values)
    """
  
    if type(data) is str:
        text = data
    else:
        # * is p < 0.05
        # ** is p < 0.005
        # *** is p < 0.0005
        # ↓↓↓↓↓↓↓↓↓↓↓
        # * is p < 0.05
        # ** is p < 0.01
        # *** is p < 0.001
        # etc.
        text = ''
        p = .05
  
        while data < p:
            text += '*'
            p /= 10.
  
            if maxasterix and len(text) == maxasterix:
                break
        
        if data >= 0.1:
            text = 'n. s.'
        elif data < 0.1 and data >= 0.05:
            text = '†'
        elif data < 0.05 and data >= 0.01:
            text = '*'
        elif data < 0.01 and data >= 0.001:
            text = '**'
        elif data < 0.001:
            text = '***'
        
  
    lx, ly = center[num1], height[num1]
    rx, ry = center[num2], height[num2]
  
    if yerr:
        ly += yerr[num1]
        ry += yerr[num2]
  
    ax_y0, ax_y1 = plt.gca().get_ylim()
    dh *= (ax_y1 - ax_y0)
    barh *= (ax_y1 - ax_y0)
  
    y = max(ly, ry) + dh
  
    barx = [lx, lx, rx, rx]
    bary = [y, y+barh, y+barh, y]
    mid = ((lx+rx)/2, y+barh)
  
    plt.plot(barx, bary, c='black')
  
    kwargs = dict(ha='center', va='bottom')
    if fs is not None:
        kwargs['fontsize'] = fs
  
    plt.text(*mid, text, **kwargs)
    
    #ボックス作成
    pos = plt.gca().get_position()
    s_text = "n. s. : not significant\n† : p < 0.1\n\
        * : p < 0.05\n** : p < 0.01\n*** : p < 0.001"
    dic_box = {
        'facecolor' : 'whitesmoke',
        'edgecolor' : 'black',
        'linewidth' : 1
    }

    #文字とボックスの挿入
    plt.text(5.2, 2.1, s=s_text, 
            color='black', ha='center', fontsize='13', 
            bbox=dic_box)
    

# 区切りの数
num_bins = 9

# 区切りの幅を計算
true_kic = vgg_oof['KIc']
bin_width = (np.max(true_kic) - np.min(true_kic)) / num_bins

bin_lower_min = np.min(true_kic) 
bin_upper_min = bin_lower_min + bin_width
bin_mask_min = (true_kic >= bin_lower_min) & (true_kic < bin_upper_min)

vgg_true_min = true_kic[bin_mask_min]
vgg_pred_min = predicted_kic[bin_mask_min]
vit_true_min = true_kic_vit[bin_mask_min]
vit_pred_min = predicted_kic_vit[bin_mask_min]

vgg_true_min2 = true_kic2[bin_mask_min]
vgg_pred_min2 = predicted_kic2[bin_mask_min]
vit_true_min2 = true_kic_vit2[bin_mask_min]
vit_pred_min2 = predicted_kic_vit2[bin_mask_min]

vgg_true_min3 = true_kic3[bin_mask_min]
vgg_pred_min3 = predicted_kic3[bin_mask_min]
vit_true_min3 = true_kic_vit3[bin_mask_min]
vit_pred_min3 = predicted_kic_vit3[bin_mask_min]

vgg_true_min4 = true_kic4[bin_mask_min]
vgg_pred_min4 = predicted_kic4[bin_mask_min]
vit_true_min4 = true_kic_vit4[bin_mask_min]
vit_pred_min4 = predicted_kic_vit4[bin_mask_min]

vgg_true_min5 = true_kic5[bin_mask_min]
vgg_pred_min5 = predicted_kic5[bin_mask_min]
vit_true_min5 = true_kic_vit5[bin_mask_min]
vit_pred_min5 = predicted_kic_vit5[bin_mask_min]

vit_pred = [np.mean(vit_pred_min), np.mean(vit_pred_min2), np.mean(vit_pred_min3), 
            np.mean(vit_pred_min4), np.mean(vit_pred_min5)]
vgg_pred = [np.mean(vgg_pred_min), np.mean(vgg_pred_min2), np.mean(vgg_pred_min3), 
            np.mean(vgg_pred_min4), np.mean(vgg_pred_min5)]

results = stats.ttest_rel(vgg_pred, vit_pred, alternative='greater')
print(results)

# データの作成
data = pd.DataFrame({
    'Method': ['ViT'] * 5 + ['VGG'] * 5,
    'Pred KIc': np.concatenate([vit_pred, vgg_pred], 0)
})

# 箱ひげ図と点を結ぶグラフの描画
plt.figure(figsize=(5, 5))
plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23 

""" plot """
x0 = vit_pred
x1 = vgg_pred
heights = [0, np.mean(x0), 0, np.mean(x1), 0]
std = [0, np.std(x0)/np.sqrt(5), 0, np.std(x1)/np.sqrt(5), 0]
label = ['', 'ViT', '', 'VGG', '']
width = 0.8 # the width of the bars
bars = np.arange(5)

barplot_annotate_brackets(1, 3, round(results.pvalue, 4), bars, heights, yerr=std, dh=.08)

plt.xticks([0, 1, 2, 3, 4], ['', 'ViT', '', 'VGG', ''])
# 各点を結ぶ線の描画
for i in range(0, 5):
    method1 = vit_pred[i]
    method2 = vgg_pred[i]
    plt.plot([1, 3], [method1, method2], color="black", 
             marker='.', markersize=12, linestyle="-", linewidth=2)   

# グラフの装飾
plt.xlabel("Method")
plt.ylabel("Pred KIc")
plt.ylim(1.7, 2.4)
plt.xlim(0, 4)
plt.title("Paired t-test(low KIc)")
plt.savefig('./Figure/paired_ttest.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# TtestResult(statistic=9.028379877737525, pvalue=0.0004168418077429046, df=4)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def barplot_annotate_brackets(num1, num2, data, center, 
                              height, yerr=None, dh=.05, 
                              barh=.05, fs=None, maxasterix=None):
    """ 
    Annotate barplot with p-values.
  
    :param num1: number of left bar to put bracket over
    :param num2: number of right bar to put bracket over
    :param data: string to write or number for generating asterixes
    :param center: centers of all bars (like plt.bar() input)
    :param height: heights of all bars (like plt.bar() input)
    :param yerr: yerrs of all bars (like plt.bar() input)
    :param dh: height offset over bar / bar + yerr in axes coordinates (0 to 1)
    :param barh: bar height in axes coordinates (0 to 1)
    :param fs: font size
    :param maxasterix: maximum number of asterixes to write (for very small p-values)
    """
  
    if type(data) is str:
        text = data
    else:
        # * is p < 0.05
        # ** is p < 0.005
        # *** is p < 0.0005
        # ↓↓↓↓↓↓↓↓↓↓↓
        # * is p < 0.05
        # ** is p < 0.01
        # *** is p < 0.001
        # etc.
        text = ''
        p = .05
  
        while data < p:
            text += '*'
            p /= 10.
  
            if maxasterix and len(text) == maxasterix:
                break
        
        if data >= 0.1:
            text = 'n. s.'
        elif data < 0.1 and data >= 0.05:
            text = '†'
        elif data < 0.05 and data >= 0.01:
            text = '*'
        elif data < 0.01 and data >= 0.001:
            text = '**'
        elif data < 0.001:
            text = '***'
        
  
    lx, ly = center[num1], height[num1]
    rx, ry = center[num2], height[num2]
  
    if yerr:
        ly += yerr[num1]
        ry += yerr[num2]
  
    ax_y0, ax_y1 = plt.gca().get_ylim()
    dh *= (ax_y1 - ax_y0)
    barh *= (ax_y1 - ax_y0)
  
    y = max(ly, ry) + dh
  
    barx = [lx, lx, rx, rx]
    bary = [y, y+barh, y+barh, y]
    mid = ((lx+rx)/2, y+barh)
  
    plt.plot(barx, bary, c='black')
  
    kwargs = dict(ha='center', va='bottom')
    if fs is not None:
        kwargs['fontsize'] = fs
  
    plt.text(*mid, text, **kwargs)
    
    #ボックス作成
    pos = plt.gca().get_position()
    s_text = "n. s. : not significant\n† : p < 0.1\n* : p < 0.05\n** : p < 0.01\n*** : p < 0.001"
    dic_box = {
        'facecolor' : 'whitesmoke',
        'edgecolor' : 'black',
        'linewidth' : 1
    }

    #文字とボックスの挿入
    plt.text(5.2, 4.3, s=s_text, 
            color='black', ha='center', fontsize='13', 
            bbox=dic_box)


bin_lower_max = np.min(true_kic) + num_bins * bin_width
bin_upper_max = bin_lower_max + bin_width
bin_mask_max = (true_kic >= bin_lower_max) & (true_kic < bin_upper_max)

vgg_true_max = true_kic[bin_mask_max]
vgg_pred_max = predicted_kic[bin_mask_max]
vit_true_max = true_kic_vit[bin_mask_max]
vit_pred_max = predicted_kic_vit[bin_mask_max]

vgg_true_max2 = true_kic2[bin_mask_max]
vgg_pred_max2 = predicted_kic2[bin_mask_max]
vit_true_max2 = true_kic_vit2[bin_mask_max]
vit_pred_max2 = predicted_kic_vit2[bin_mask_max]

vgg_true_max3 = true_kic3[bin_mask_max]
vgg_pred_max3 = predicted_kic3[bin_mask_max]
vit_true_max3 = true_kic_vit3[bin_mask_max]
vit_pred_max3 = predicted_kic_vit3[bin_mask_max]

vgg_true_max4 = true_kic4[bin_mask_max]
vgg_pred_max4 = predicted_kic4[bin_mask_max]
vit_true_max4 = true_kic_vit4[bin_mask_max]
vit_pred_max4 = predicted_kic_vit4[bin_mask_max]

vgg_true_max5 = true_kic5[bin_mask_max]
vgg_pred_max5 = predicted_kic5[bin_mask_max]
vit_true_max5 = true_kic_vit5[bin_mask_max]
vit_pred_max5 = predicted_kic_vit5[bin_mask_max]

vit_pred = [np.mean(vit_pred_max), np.mean(vit_pred_max2), np.mean(vit_pred_max3), 
np.mean(vit_pred_max4), np.mean(vit_pred_max5)]
vgg_pred = [np.mean(vgg_pred_max), np.mean(vgg_pred_max2), np.mean(vgg_pred_max3), 
np.mean(vgg_pred_max4), np.mean(vgg_pred_max5)]

results = stats.ttest_rel(vgg_pred, vit_pred, alternative='less')
print(results)
# データの作成
data = pd.DataFrame({
    'Method': ['VGG'] * 5 + ['ViT'] * 5,
    'Pred KIc': np.concatenate([vgg_pred, vit_pred], 0)
})

# 箱ひげ図と点を結ぶグラフの描画
plt.figure(figsize=(5, 5))

plt.rcParams['figure.figsize'] = 17,5
plt.rcParams["font.size"] = 23 

plt.xticks([0, 1, 2, 3, 4], ['', 'ViT', '', 'VGG', ''])
# 各点を結ぶ線の描画
for i in range(0, 5):
    method1 = vit_pred[i]
    method2 = vgg_pred[i]
    plt.plot([1, 3], [method1, method2], color="black", marker='.', 
             markersize=12, linestyle="-", linewidth=2)   

""" plot """
x0 = vit_pred
x1 = vgg_pred
heights = [0, np.mean(x0), 0, np.mean(x1), 0]
std = [0, np.std(x0)/np.sqrt(5), 0, np.std(x1)/np.sqrt(5), 0]
label = ['', 'ViT', '', 'VGG', '']
width = 0.8 # the width of the bars
bars = np.arange(5)

barplot_annotate_brackets(1, 3, results.pvalue, bars,
                          heights, yerr=std, dh=.45)

# グラフの装飾
plt.xlabel("Method")
plt.ylabel("Pred KIc")
plt.ylim(4, 4.5)
plt.xlim(0, 4)
plt.title("Paired t-test(high KIc)")
plt.savefig('./Figure/paired_ttest.eps', bbox_inches="tight", pad_inches=0.05)
plt.show()
# Out:
# TtestResult(statistic=-1.870054098017501, pvalue=0.06741133649279872, df=4)
